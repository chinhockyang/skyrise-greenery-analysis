# %% [markdown]
# **RETRIEVING FULL ADDRESS WITH ONEMAP API**

# %%
import pandas as pd 

hdb_property = pd.read_csv('resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv')

# %%
hdb_property.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %%
hdb_property['address'] = hdb_property['block'] + ' ' + hdb_property['street_name']

# %%
hdb_property.to_csv('hdb_resale_prices.csv')

# %%
import requests

# %%
# For addresses with no postal code
def get_postal_codes(df):
    codes = []
    addresses = df['address']
    num = 0

    for x in addresses:
        search_string = str(x)
        onemap_url = "https://developers.onemap.sg/commonapi/search"
        search_params = {
            "searchVal": search_string,
            "returnGeom": "Y",
            "getAddrDetails": "Y",
            "pageNum": 1,
        }

        res = requests.get(onemap_url, params=search_params, timeout=10000)
        print(f"Request returned status code {res.status_code}")
        res = res.json()
        if res['found'] == 1:
            # should append a list so that each list item represents a singular postal code
            codes.append([search_string,
                        res['results'][0]['BLK_NO'],
                        res['results'][0]['ROAD_NAME'],
                        res['results'][0]['BUILDING'],
                        res['results'][0]['POSTAL'],
                        res['results'][0]['LATITUDE'],
                        res['results'][0]['LONGITUDE']])
                    
        elif res['found'] > 1:
            codes.append([search_string,
                        res['results'][0]['BLK_NO'],
                        res['results'][0]['ROAD_NAME'],
                        'UNKNOWN',
                        res['results'][0]['POSTAL'],
                        res['results'][0]['LATITUDE'],
                        res['results'][0]['LONGITUDE']])

        else: 
            codes.append([search_string, 'NotFound', 'NotFound', 'NotFound', 'NotFound'])
        
        num += 1
        print(num)


    df = pd.DataFrame(codes, columns=["ADDRESS", "BLK_NO", "STREET_NAME", "BUILDING_NAME", "POSTAL_CODE", "LATITUDE", "LONGITUDE"])

    return df

# %%
address = get_postal_codes(hdb_property)
# Out:
# Request returned status code 200
# 1
# Request returned status code 200
# 2
# Request returned status code 200
# 3
# Request returned status code 200
# 4
# Request returned status code 200
# 5
# Request returned status code 200
# 6
# Request returned status code 200
# 7
# Request returned status code 200
# 8
# Request returned status code 200
# 9
# Request returned status code 200
# 10
# Request returned status code 200
# 11
# Request returned status code 200
# 12
# Request returned status code 200
# 13
# Request returned status code 200
# 14
# Request returned status code 200
# 15
# Request returned status code 200
# 16
# Request returned status code 200
# 17
# Request returned status code 200
# 18
# Request returned status code 200
# 19
# Request returned status code 200
# 20
# Request returned status code 200
# 21
# Request returned status code 200
# 22
# Request returned status code 200
# 23
# Request returned status code 200
# 24
# Request returned status code 200
# 25
# Request returned status code 200
# 26
# Request returned status code 200
# 27
# Request returned status code 200
# 28
# Request returned status code 200
# 29
# Request returned status code 200
# 30
# Request returned status code 200
# 31
# Request returned status code 200
# 32
# Request returned status code 200
# 33
# Request returned status code 200
# 34
# Request returned status code 200
# 35
# Request returned status code 200
# 36
# Request returned status code 200
# 37
# Request returned status code 200
# 38
# Request returned status code 200
# 39
# Request returned status code 200
# 40
# Request returned status code 200
# 41
# Request returned status code 200
# 42
# Request returned status code 200
# 43
# Request returned status code 200
# 44
# Request returned status code 200
# 45
# Request returned status code 200
# 46
# Request returned status code 200
# 47
# Request returned status code 200
# 48
# Request returned status code 200
# 49
# Request returned status code 200
# 50
# Request returned status code 200
# 51
# Request returned status code 200
# 52
# Request returned status code 200
# 53
# Request returned status code 200
# 54
# Request returned status code 200
# 55
# Request returned status code 200
# 56
# Request returned status code 200
# 57
# Request returned status code 200
# 58
# Request returned status code 200
# 59
# Request returned status code 200
# 60
# Request returned status code 200
# 61
# Request returned status code 200
# 62
# Request returned status code 200
# 63
# Request returned status code 200
# 64
# Request returned status code 200
# 65
# Request returned status code 200
# 66
# Request returned status code 200
# 67
# Request returned status code 200
# 68
# Request returned status code 200
# 69
# Request returned status code 200
# 70
# Request returned status code 200
# 71
# Request returned status code 200
# 72
# Request returned status code 200
# 73
# Request returned status code 200
# 74
# Request returned status code 200
# 75
# Request returned status code 200
# 76
# Request returned status code 200
# 77
# Request returned status code 200
# 78
# Request returned status code 200
# 79
# Request returned status code 200
# 80
# Request returned status code 200
# 81
# Request returned status code 200
# 82
# Request returned status code 200
# 83
# Request returned status code 200
# 84
# Request returned status code 200
# 85
# Request returned status code 200
# 86
# Request returned status code 200
# 87
# Request returned status code 200
# 88
# Request returned status code 200
# 89
# Request returned status code 200
# 90
# Request returned status code 200
# 91
# Request returned status code 200
# 92
# Request returned status code 200
# 93
# Request returned status code 200
# 94
# Request returned status code 200
# 95
# Request returned status code 200
# 96
# Request returned status code 200
# 97
# Request returned status code 200
# 98
# Request returned status code 200
# 99
# Request returned status code 200
# 100
# Request returned status code 200
# 101
# Request returned status code 200
# 102
# Request returned status code 200
# 103
# Request returned status code 200
# 104
# Request returned status code 200
# 105
# Request returned status code 200
# 106
# Request returned status code 200
# 107
# Request returned status code 200
# 108
# Request returned status code 200
# 109
# Request returned status code 200
# 110
# Request returned status code 200
# 111
# Request returned status code 200
# 112
# Request returned status code 200
# 113
# Request returned status code 200
# 114
# Request returned status code 200
# 115
# Request returned status code 200
# 116
# Request returned status code 200
# 117
# Request returned status code 200
# 118
# Request returned status code 200
# 119
# Request returned status code 200
# 120
# Request returned status code 200
# 121
# Request returned status code 200
# 122
# Request returned status code 200
# 123
# Request returned status code 200
# 124
# Request returned status code 200
# 125
# Request returned status code 200
# 126
# Request returned status code 200
# 127
# Request returned status code 200
# 128
# Request returned status code 200
# 129
# Request returned status code 200
# 130
# Request returned status code 200
# 131
# Request returned status code 200
# 132
# Request returned status code 200
# 133
# Request returned status code 200
# 134
# Request returned status code 200
# 135
# Request returned status code 200
# 136
# Request returned status code 200
# 137
# Request returned status code 200
# 138
# Request returned status code 200
# 139
# Request returned status code 200
# 140
# Request returned status code 200
# 141
# Request returned status code 200
# 142
# Request returned status code 200
# 143
# Request returned status code 200
# 144
# Request returned status code 200
# 145
# Request returned status code 200
# 146
# Request returned status code 200
# 147
# Request returned status code 200
# 148
# Request returned status code 200
# 149
# Request returned status code 200
# 150
# Request returned status code 200
# 151
# Request returned status code 200
# 152
# Request returned status code 200
# 153
# Request returned status code 200
# 154
# Request returned status code 200
# 155
# Request returned status code 200
# 156
# Request returned status code 200
# 157
# Request returned status code 200
# 158
# Request returned status code 200
# 159
# Request returned status code 200
# 160
# Request returned status code 200
# 161
# Request returned status code 200
# 162
# Request returned status code 200
# 163
# Request returned status code 200
# 164
# Request returned status code 200
# 165
# Request returned status code 200
# 166
# Request returned status code 200
# 167
# Request returned status code 200
# 168
# Request returned status code 200
# 169
# Request returned status code 200
# 170
# Request returned status code 200
# 171
# Request returned status code 200
# 172
# Request returned status code 200
# 173
# Request returned status code 200
# 174
# Request returned status code 200
# 175
# Request returned status code 200
# 176
# Request returned status code 200
# 177
# Request returned status code 200
# 178
# Request returned status code 200
# 179
# Request returned status code 200
# 180
# Request returned status code 200
# 181
# Request returned status code 200
# 182
# Request returned status code 200
# 183
# Request returned status code 200
# 184
# Request returned status code 200
# 185
# Request returned status code 200
# 186
# Request returned status code 200
# 187
# Request returned status code 200
# 188
# Request returned status code 200
# 189
# Request returned status code 200
# 190
# Request returned status code 200
# 191
# Request returned status code 200
# 192
# Request returned status code 200
# 193
# Request returned status code 200
# 194
# Request returned status code 200
# 195
# Request returned status code 200
# 196
# Request returned status code 200
# 197
# Request returned status code 200
# 198
# Request returned status code 200
# 199
# Request returned status code 200
# 200
# Request returned status code 200
# 201
# Request returned status code 200
# 202
# Request returned status code 200
# 203
# Request returned status code 200
# 204
# Request returned status code 200
# 205
# Request returned status code 200
# 206
# Request returned status code 200
# 207
# Request returned status code 200
# 208
# Request returned status code 200
# 209
# Request returned status code 200
# 210
# Request returned status code 200
# 211
# Request returned status code 200
# 212
# Request returned status code 200
# 213
# Request returned status code 200
# 214
# Request returned status code 200
# 215
# Request returned status code 200
# 216
# Request returned status code 200
# 217
# Request returned status code 200
# 218
# Request returned status code 200
# 219
# Request returned status code 200
# 220
# Request returned status code 200
# 221
# Request returned status code 200
# 222
# Request returned status code 200
# 223
# Request returned status code 200
# 224
# Request returned status code 200
# 225
# Request returned status code 200
# 226
# Request returned status code 200
# 227
# Request returned status code 200
# 228
# Request returned status code 200
# 229
# Request returned status code 200
# 230
# Request returned status code 200
# 231
# Request returned status code 200
# 232
# Request returned status code 200
# 233
# Request returned status code 200
# 234
# Request returned status code 200
# 235
# Request returned status code 200
# 236
# Request returned status code 200
# 237
# Request returned status code 200
# 238
# Request returned status code 200
# 239
# Request returned status code 200
# 240
# Request returned status code 200
# 241
# Request returned status code 200
# 242
# Request returned status code 200
# 243
# Request returned status code 200
# 244
# Request returned status code 200
# 245
# Request returned status code 200
# 246
# Request returned status code 200
# 247
# Request returned status code 200
# 248
# Request returned status code 200
# 249
# Request returned status code 200
# 250
# Request returned status code 200
# 251
# Request returned status code 200
# 252
# Request returned status code 200
# 253
# Request returned status code 200
# 254
# Request returned status code 200
# 255
# Request returned status code 200
# 256
# Request returned status code 200
# 257
# Request returned status code 200
# 258
# Request returned status code 200
# 259
# Request returned status code 200
# 260
# Request returned status code 200
# 261
# Request returned status code 200
# 262
# Request returned status code 200
# 263
# Request returned status code 200
# 264
# Request returned status code 200
# 265
# Request returned status code 200
# 266
# Request returned status code 200
# 267
# Request returned status code 200
# 268
# Request returned status code 200
# 269
# Request returned status code 200
# 270
# Request returned status code 200
# 271
# Request returned status code 200
# 272
# Request returned status code 200
# 273
# Request returned status code 200
# 274
# Request returned status code 200
# 275
# Request returned status code 200
# 276
# Request returned status code 200
# 277
# Request returned status code 200
# 278
# Request returned status code 200
# 279
# Request returned status code 200
# 280
# Request returned status code 200
# 281
# Request returned status code 200
# 282
# Request returned status code 200
# 283
# Request returned status code 200
# 284
# Request returned status code 200
# 285
# Request returned status code 200
# 286
# Request returned status code 200
# 287
# Request returned status code 200
# 288
# Request returned status code 200
# 289
# Request returned status code 200
# 290
# Request returned status code 200
# 291
# Request returned status code 200
# 292
# Request returned status code 200
# 293
# Request returned status code 200
# 294
# Request returned status code 200
# 295
# Request returned status code 200
# 296
# Request returned status code 200
# 297
# Request returned status code 200
# 298
# Request returned status code 200
# 299
# Request returned status code 200
# 300
# Request returned status code 200
# 301
# Request returned status code 200
# 302
# Request returned status code 200
# 303
# Request returned status code 200
# 304
# Request returned status code 200
# 305
# Request returned status code 200
# 306
# Request returned status code 200
# 307
# Request returned status code 200
# 308
# Request returned status code 200
# 309
# Request returned status code 200
# 310
# Request returned status code 200
# 311
# Request returned status code 200
# 312
# Request returned status code 200
# 313
# Request returned status code 200
# 314
# Request returned status code 200
# 315
# Request returned status code 200
# 316
# Request returned status code 200
# 317
# Request returned status code 200
# 318
# Request returned status code 200
# 319
# Request returned status code 200
# 320
# Request returned status code 200
# 321
# Request returned status code 200
# 322
# Request returned status code 200
# 323
# Request returned status code 200
# 324
# Request returned status code 200
# 325
# Request returned status code 200
# 326
# Request returned status code 200
# 327
# Request returned status code 200
# 328
# Request returned status code 200
# 329
# Request returned status code 200
# 330
# Request returned status code 200
# 331
# Request returned status code 200
# 332
# Request returned status code 200
# 333
# Request returned status code 200
# 334
# Request returned status code 200
# 335
# Request returned status code 200
# 336
# Request returned status code 200
# 337
# Request returned status code 200
# 338
# Request returned status code 200
# 339
# Request returned status code 200
# 340
# Request returned status code 200
# 341
# Request returned status code 200
# 342
# Request returned status code 200
# 343
# Request returned status code 200
# 344
# Request returned status code 200
# 345
# Request returned status code 200
# 346
# Request returned status code 200
# 347
# Request returned status code 200
# 348
# Request returned status code 200
# 349
# Request returned status code 200
# 350
# Request returned status code 200
# 351
# Request returned status code 200
# 352
# Request returned status code 200
# 353
# Request returned status code 200
# 354
# Request returned status code 200
# 355
# Request returned status code 200
# 356
# Request returned status code 200
# 357
# Request returned status code 200
# 358
# Request returned status code 200
# 359
# Request returned status code 200
# 360
# Request returned status code 200
# 361
# Request returned status code 200
# 362
# Request returned status code 200
# 363
# Request returned status code 200
# 364
# Request returned status code 200
# 365
# Request returned status code 200
# 366
# Request returned status code 200
# 367
# Request returned status code 200
# 368
# Request returned status code 200
# 369
# Request returned status code 200
# 370
# Request returned status code 200
# 371
# Request returned status code 200
# 372
# Request returned status code 200
# 373
# Request returned status code 200
# 374
# Request returned status code 200
# 375
# Request returned status code 200
# 376
# Request returned status code 200
# 377
# Request returned status code 200
# 378
# Request returned status code 200
# 379
# Request returned status code 200
# 380
# Request returned status code 200
# 381
# Request returned status code 200
# 382
# Request returned status code 200
# 383
# Request returned status code 200
# 384
# Request returned status code 200
# 385
# Request returned status code 200
# 386
# Request returned status code 200
# 387
# Request returned status code 200
# 388
# Request returned status code 200
# 389
# Request returned status code 200
# 390
# Request returned status code 200
# 391
# Request returned status code 200
# 392
# Request returned status code 200
# 393
# Request returned status code 200
# 394
# Request returned status code 200
# 395
# Request returned status code 200
# 396
# Request returned status code 200
# 397
# Request returned status code 200
# 398
# Request returned status code 200
# 399
# Request returned status code 200
# 400
# Request returned status code 200
# 401
# Request returned status code 200
# 402
# Request returned status code 200
# 403
# Request returned status code 200
# 404
# Request returned status code 200
# 405
# Request returned status code 200
# 406
# Request returned status code 200
# 407
# Request returned status code 200
# 408
# Request returned status code 200
# 409
# Request returned status code 200
# 410
# Request returned status code 200
# 411
# Request returned status code 200
# 412
# Request returned status code 200
# 413
# Request returned status code 200
# 414
# Request returned status code 200
# 415
# Request returned status code 200
# 416
# Request returned status code 200
# 417
# Request returned status code 200
# 418
# Request returned status code 200
# 419
# Request returned status code 200
# 420
# Request returned status code 200
# 421
# Request returned status code 200
# 422
# Request returned status code 200
# 423
# Request returned status code 200
# 424
# Request returned status code 200
# 425
# Request returned status code 200
# 426
# Request returned status code 200
# 427
# Request returned status code 200
# 428
# Request returned status code 200
# 429
# Request returned status code 200
# 430
# Request returned status code 200
# 431
# Request returned status code 200
# 432
# Request returned status code 200
# 433
# Request returned status code 200
# 434
# Request returned status code 200
# 435
# Request returned status code 200
# 436
# Request returned status code 200
# 437
# Request returned status code 200
# 438
# Request returned status code 200
# 439
# Request returned status code 200
# 440
# Request returned status code 200
# 441
# Request returned status code 200
# 442
# Request returned status code 200
# 443
# Request returned status code 200
# 444
# Request returned status code 200
# 445
# Request returned status code 200
# 446
# Request returned status code 200
# 447
# Request returned status code 200
# 448
# Request returned status code 200
# 449
# Request returned status code 200
# 450
# Request returned status code 200
# 451
# Request returned status code 200
# 452
# Request returned status code 200
# 453
# Request returned status code 200
# 454
# Request returned status code 200
# 455
# Request returned status code 200
# 456
# Request returned status code 200
# 457
# Request returned status code 200
# 458
# Request returned status code 200
# 459
# Request returned status code 200
# 460
# Request returned status code 200
# 461
# Request returned status code 200
# 462
# Request returned status code 200
# 463
# Request returned status code 200
# 464
# Request returned status code 200
# 465
# Request returned status code 200
# 466
# Request returned status code 200
# 467
# Request returned status code 200
# 468
# Request returned status code 200
# 469
# Request returned status code 200
# 470
# Request returned status code 200
# 471
# Request returned status code 200
# 472
# Request returned status code 200
# 473
# Request returned status code 200
# 474
# Request returned status code 200
# 475
# Request returned status code 200
# 476
# Request returned status code 200
# 477
# Request returned status code 200
# 478
# Request returned status code 200
# 479
# Request returned status code 200
# 480
# Request returned status code 200
# 481
# Request returned status code 200
# 482
# Request returned status code 200
# 483
# Request returned status code 200
# 484
# Request returned status code 200
# 485
# Request returned status code 200
# 486
# Request returned status code 200
# 487
# Request returned status code 200
# 488
# Request returned status code 200
# 489
# Request returned status code 200
# 490
# Request returned status code 200
# 491
# Request returned status code 200
# 492
# Request returned status code 200
# 493
# Request returned status code 200
# 494
# Request returned status code 200
# 495
# Request returned status code 200
# 496
# Request returned status code 200
# 497
# Request returned status code 200
# 498
# Request returned status code 200
# 499
# Request returned status code 200
# 500
# Request returned status code 200
# 501
# Request returned status code 200
# 502
# Request returned status code 200
# 503
# Request returned status code 200
# 504
# Request returned status code 200
# 505
# Request returned status code 200
# 506
# Request returned status code 200
# 507
# Request returned status code 200
# 508
# Request returned status code 200
# 509
# Request returned status code 200
# 510
# Request returned status code 200
# 511
# Request returned status code 200
# 512
# Request returned status code 200
# 513
# Request returned status code 200
# 514
# Request returned status code 200
# 515
# Request returned status code 200
# 516
# Request returned status code 200
# 517
# Request returned status code 200
# 518
# Request returned status code 200
# 519
# Request returned status code 200
# 520
# Request returned status code 200
# 521
# Request returned status code 200
# 522
# Request returned status code 200
# 523
# Request returned status code 200
# 524
# Request returned status code 200
# 525
# Request returned status code 200
# 526
# Request returned status code 200
# 527
# Request returned status code 200
# 528
# Request returned status code 200
# 529
# Request returned status code 200
# 530
# Request returned status code 200
# 531
# Request returned status code 200
# 532
# Request returned status code 200
# 533
# Request returned status code 200
# 534
# Request returned status code 200
# 535
# Request returned status code 200
# 536
# Request returned status code 200
# 537
# Request returned status code 200
# 538
# Request returned status code 200
# 539
# Request returned status code 200
# 540
# Request returned status code 200
# 541
# Request returned status code 200
# 542
# Request returned status code 200
# 543
# Request returned status code 200
# 544
# Request returned status code 200
# 545
# Request returned status code 200
# 546
# Request returned status code 200
# 547
# Request returned status code 200
# 548
# Request returned status code 200
# 549
# Request returned status code 200
# 550
# Request returned status code 200
# 551
# Request returned status code 200
# 552
# Request returned status code 200
# 553
# Request returned status code 200
# 554
# Request returned status code 200
# 555
# Request returned status code 200
# 556
# Request returned status code 200
# 557
# Request returned status code 200
# 558
# Request returned status code 200
# 559
# Request returned status code 200
# 560
# Request returned status code 200
# 561
# Request returned status code 200
# 562
# Request returned status code 200
# 563
# Request returned status code 200
# 564
# Request returned status code 200
# 565
# Request returned status code 200
# 566
# Request returned status code 200
# 567
# Request returned status code 200
# 568
# Request returned status code 200
# 569
# Request returned status code 200
# 570
# Request returned status code 200
# 571
# Request returned status code 200
# 572
# Request returned status code 200
# 573
# Request returned status code 200
# 574
# Request returned status code 200
# 575
# Request returned status code 200
# 576
# Request returned status code 200
# 577
# Request returned status code 200
# 578
# Request returned status code 200
# 579
# Request returned status code 200
# 580
# Request returned status code 200
# 581
# Request returned status code 200
# 582
# Request returned status code 200
# 583
# Request returned status code 200
# 584
# Request returned status code 200
# 585
# Request returned status code 200
# 586
# Request returned status code 200
# 587
# Request returned status code 200
# 588
# Request returned status code 200
# 589
# Request returned status code 200
# 590
# Request returned status code 200
# 591
# Request returned status code 200
# 592
# Request returned status code 200
# 593
# Request returned status code 200
# 594
# Request returned status code 200
# 595
# Request returned status code 200
# 596
# Request returned status code 200
# 597
# Request returned status code 200
# 598
# Request returned status code 200
# 599
# Request returned status code 200
# 600
# Request returned status code 200
# 601
# Request returned status code 200
# 602
# Request returned status code 200
# 603
# Request returned status code 200
# 604
# Request returned status code 200
# 605
# Request returned status code 200
# 606
# Request returned status code 200
# 607
# Request returned status code 200
# 608
# Request returned status code 200
# 609
# Request returned status code 200
# 610
# Request returned status code 200
# 611
# Request returned status code 200
# 612
# Request returned status code 200
# 613
# Request returned status code 200
# 614
# Request returned status code 200
# 615
# Request returned status code 200
# 616
# Request returned status code 200
# 617
# Request returned status code 200
# 618
# Request returned status code 200
# 619
# Request returned status code 200
# 620
# Request returned status code 200
# 621
# Request returned status code 200
# 622
# Request returned status code 200
# 623
# Request returned status code 200
# 624
# Request returned status code 200
# 625
# Request returned status code 200
# 626
# Request returned status code 200
# 627
# Request returned status code 200
# 628
# Request returned status code 200
# 629
# Request returned status code 200
# 630
# Request returned status code 200
# 631
# Request returned status code 200
# 632
# Request returned status code 200
# 633
# Request returned status code 200
# 634
# Request returned status code 200
# 635
# Request returned status code 200
# 636
# Request returned status code 200
# 637
# Request returned status code 200
# 638
# Request returned status code 200
# 639
# Request returned status code 200
# 640
# Request returned status code 200
# 641
# Request returned status code 200
# 642
# Request returned status code 200
# 643
# Request returned status code 200
# 644
# Request returned status code 200
# 645
# Request returned status code 200
# 646
# Request returned status code 200
# 647
# Request returned status code 200
# 648
# Request returned status code 200
# 649
# Request returned status code 200
# 650
# Request returned status code 200
# 651
# Request returned status code 200
# 652
# Request returned status code 200
# 653
# Request returned status code 200
# 654
# Request returned status code 200
# 655
# Request returned status code 200
# 656
# Request returned status code 200
# 657
# Request returned status code 200
# 658
# Request returned status code 200
# 659
# Request returned status code 200
# 660
# Request returned status code 200
# 661
# Request returned status code 200
# 662
# Request returned status code 200
# 663
# Request returned status code 200
# 664
# Request returned status code 200
# 665
# Request returned status code 200
# 666
# Request returned status code 200
# 667
# Request returned status code 200
# 668
# Request returned status code 200
# 669
# Request returned status code 200
# 670
# Request returned status code 200
# 671
# Request returned status code 200
# 672
# Request returned status code 200
# 673
# Request returned status code 200
# 674
# Request returned status code 200
# 675
# Request returned status code 200
# 676
# Request returned status code 200
# 677
# Request returned status code 200
# 678
# Request returned status code 200
# 679
# Request returned status code 200
# 680
# Request returned status code 200
# 681
# Request returned status code 200
# 682
# Request returned status code 200
# 683
# Request returned status code 200
# 684
# Request returned status code 200
# 685
# Request returned status code 200
# 686
# Request returned status code 200
# 687
# Request returned status code 200
# 688
# Request returned status code 200
# 689
# Request returned status code 200
# 690
# Request returned status code 200
# 691
# Request returned status code 200
# 692
# Request returned status code 200
# 693
# Request returned status code 200
# 694
# Request returned status code 200
# 695
# Request returned status code 200
# 696
# Request returned status code 200
# 697
# Request returned status code 200
# 698
# Request returned status code 200
# 699
# Request returned status code 200
# 700
# Request returned status code 200
# 701
# Request returned status code 200
# 702
# Request returned status code 200
# 703
# Request returned status code 200
# 704
# Request returned status code 200
# 705
# Request returned status code 200
# 706
# Request returned status code 200
# 707
# Request returned status code 200
# 708
# Request returned status code 200
# 709
# Request returned status code 200
# 710
# Request returned status code 200
# 711
# Request returned status code 200
# 712
# Request returned status code 200
# 713
# Request returned status code 200
# 714
# Request returned status code 200
# 715
# Request returned status code 200
# 716
# Request returned status code 200
# 717
# Request returned status code 200
# 718
# Request returned status code 200
# 719
# Request returned status code 200
# 720
# Request returned status code 200
# 721
# Request returned status code 200
# 722
# Request returned status code 200
# 723
# Request returned status code 200
# 724
# Request returned status code 200
# 725
# Request returned status code 200
# 726
# Request returned status code 200
# 727
# Request returned status code 200
# 728
# Request returned status code 200
# 729
# Request returned status code 200
# 730
# Request returned status code 200
# 731
# Request returned status code 200
# 732
# Request returned status code 200
# 733
# Request returned status code 200
# 734
# Request returned status code 200
# 735
# Request returned status code 200
# 736
# Request returned status code 200
# 737
# Request returned status code 200
# 738
# Request returned status code 200
# 739
# Request returned status code 200
# 740
# Request returned status code 200
# 741
# Request returned status code 200
# 742
# Request returned status code 200
# 743
# Request returned status code 200
# 744
# Request returned status code 200
# 745
# Request returned status code 200
# 746
# Request returned status code 200
# 747
# Request returned status code 200
# 748
# Request returned status code 200
# 749
# Request returned status code 200
# 750
# Request returned status code 200
# 751
# Request returned status code 200
# 752
# Request returned status code 200
# 753
# Request returned status code 200
# 754
# Request returned status code 200
# 755
# Request returned status code 200
# 756
# Request returned status code 200
# 757
# Request returned status code 200
# 758
# Request returned status code 200
# 759
# Request returned status code 200
# 760
# Request returned status code 200
# 761
# Request returned status code 200
# 762
# Request returned status code 200
# 763
# Request returned status code 200
# 764
# Request returned status code 200
# 765
# Request returned status code 200
# 766
# Request returned status code 200
# 767
# Request returned status code 200
# 768
# Request returned status code 200
# 769
# Request returned status code 200
# 770
# Request returned status code 200
# 771
# Request returned status code 200
# 772
# Request returned status code 200
# 773
# Request returned status code 200
# 774
# Request returned status code 200
# 775
# Request returned status code 200
# 776
# Request returned status code 200
# 777
# Request returned status code 200
# 778
# Request returned status code 200
# 779
# Request returned status code 200
# 780
# Request returned status code 200
# 781
# Request returned status code 200
# 782
# Request returned status code 200
# 783
# Request returned status code 200
# 784
# Request returned status code 200
# 785
# Request returned status code 200
# 786
# Request returned status code 200
# 787
# Request returned status code 200
# 788
# Request returned status code 200
# 789
# Request returned status code 200
# 790
# Request returned status code 200
# 791
# Request returned status code 200
# 792
# Request returned status code 200
# 793
# Request returned status code 200
# 794
# Request returned status code 200
# 795
# Request returned status code 200
# 796
# Request returned status code 200
# 797
# Request returned status code 200
# 798
# Request returned status code 200
# 799
# Request returned status code 200
# 800
# Request returned status code 200
# 801
# Request returned status code 200
# 802
# Request returned status code 200
# 803
# Request returned status code 200
# 804
# Request returned status code 200
# 805
# Request returned status code 200
# 806
# Request returned status code 200
# 807
# Request returned status code 200
# 808
# Request returned status code 200
# 809
# Request returned status code 200
# 810
# Request returned status code 200
# 811
# Request returned status code 200
# 812
# Request returned status code 200
# 813
# Request returned status code 200
# 814
# Request returned status code 200
# 815
# Request returned status code 200
# 816
# Request returned status code 200
# 817
# Request returned status code 200
# 818
# Request returned status code 200
# 819
# Request returned status code 200
# 820
# Request returned status code 200
# 821
# Request returned status code 200
# 822
# Request returned status code 200
# 823
# Request returned status code 200
# 824
# Request returned status code 200
# 825
# Request returned status code 200
# 826
# Request returned status code 200
# 827
# Request returned status code 200
# 828
# Request returned status code 200
# 829
# Request returned status code 200
# 830
# Request returned status code 200
# 831
# Request returned status code 200
# 832
# Request returned status code 200
# 833
# Request returned status code 200
# 834
# Request returned status code 200
# 835
# Request returned status code 200
# 836
# Request returned status code 200
# 837
# Request returned status code 200
# 838
# Request returned status code 200
# 839
# Request returned status code 200
# 840
# Request returned status code 200
# 841
# Request returned status code 200
# 842
# Request returned status code 200
# 843
# Request returned status code 200
# 844
# Request returned status code 200
# 845
# Request returned status code 200
# 846
# Request returned status code 200
# 847
# Request returned status code 200
# 848
# Request returned status code 200
# 849
# Request returned status code 200
# 850
# Request returned status code 200
# 851
# Request returned status code 200
# 852
# Request returned status code 200
# 853
# Request returned status code 200
# 854
# Request returned status code 200
# 855
# Request returned status code 200
# 856
# Request returned status code 200
# 857
# Request returned status code 200
# 858
# Request returned status code 200
# 859
# Request returned status code 200
# 860
# Request returned status code 200
# 861
# Request returned status code 200
# 862
# Request returned status code 200
# 863
# Request returned status code 200
# 864
# Request returned status code 200
# 865
# Request returned status code 200
# 866
# Request returned status code 200
# 867
# Request returned status code 200
# 868
# Request returned status code 200
# 869
# Request returned status code 200
# 870
# Request returned status code 200
# 871
# Request returned status code 200
# 872
# Request returned status code 200
# 873
# Request returned status code 200
# 874
# Request returned status code 200
# 875
# Request returned status code 200
# 876
# Request returned status code 200
# 877
# Request returned status code 200
# 878
# Request returned status code 200
# 879
# Request returned status code 200
# 880
# Request returned status code 200
# 881
# Request returned status code 200
# 882
# Request returned status code 200
# 883
# Request returned status code 200
# 884
# Request returned status code 200
# 885
# Request returned status code 200
# 886
# Request returned status code 200
# 887
# Request returned status code 200
# 888
# Request returned status code 200
# 889
# Request returned status code 200
# 890
# Request returned status code 200
# 891
# Request returned status code 200
# 892
# Request returned status code 200
# 893
# Request returned status code 200
# 894
# Request returned status code 200
# 895
# Request returned status code 200
# 896
# Request returned status code 200
# 897
# Request returned status code 200
# 898
# Request returned status code 200
# 899
# Request returned status code 200
# 900
# Request returned status code 200
# 901
# Request returned status code 200
# 902
# Request returned status code 200
# 903
# Request returned status code 200
# 904
# Request returned status code 200
# 905
# Request returned status code 200
# 906
# Request returned status code 200
# 907
# Request returned status code 200
# 908
# Request returned status code 200
# 909
# Request returned status code 200
# 910
# Request returned status code 200
# 911
# Request returned status code 200
# 912
# Request returned status code 200
# 913
# Request returned status code 200
# 914
# Request returned status code 200
# 915
# Request returned status code 200
# 916
# Request returned status code 200
# 917
# Request returned status code 200
# 918
# Request returned status code 200
# 919
# Request returned status code 200
# 920
# Request returned status code 200
# 921
# Request returned status code 200
# 922
# Request returned status code 200
# 923
# Request returned status code 200
# 924
# Request returned status code 200
# 925
# Request returned status code 200
# 926
# Request returned status code 200
# 927
# Request returned status code 200
# 928
# Request returned status code 200
# 929
# Request returned status code 200
# 930
# Request returned status code 200
# 931
# Request returned status code 200
# 932
# Request returned status code 200
# 933
# Request returned status code 200
# 934
# Request returned status code 200
# 935
# Request returned status code 200
# 936
# Request returned status code 200
# 937
# Request returned status code 200
# 938
# Request returned status code 200
# 939
# Request returned status code 200
# 940
# Request returned status code 200
# 941
# Request returned status code 200
# 942
# Request returned status code 200
# 943
# Request returned status code 200
# 944
# Request returned status code 200
# 945
# Request returned status code 200
# 946
# Request returned status code 200
# 947
# Request returned status code 200
# 948
# Request returned status code 200
# 949
# Request returned status code 200
# 950
# Request returned status code 200
# 951
# Request returned status code 200
# 952
# Request returned status code 200
# 953
# Request returned status code 200
# 954
# Request returned status code 200
# 955
# Request returned status code 200
# 956
# Request returned status code 200
# 957
# Request returned status code 200
# 958
# Request returned status code 200
# 959
# Request returned status code 200
# 960
# Request returned status code 200
# 961
# Request returned status code 200
# 962
# Request returned status code 200
# 963
# Request returned status code 200
# 964
# Request returned status code 200
# 965
# Request returned status code 200
# 966
# Request returned status code 200
# 967
# Request returned status code 200
# 968
# Request returned status code 200
# 969
# Request returned status code 200
# 970
# Request returned status code 200
# 971
# Request returned status code 200
# 972
# Request returned status code 200
# 973
# Request returned status code 200
# 974
# Request returned status code 200
# 975
# Request returned status code 200
# 976
# Request returned status code 200
# 977
# Request returned status code 200
# 978
# Request returned status code 200
# 979
# Request returned status code 200
# 980
# Request returned status code 200
# 981
# Request returned status code 200
# 982
# Request returned status code 200
# 983
# Request returned status code 200
# 984
# Request returned status code 200
# 985
# Request returned status code 200
# 986
# Request returned status code 200
# 987
# Request returned status code 200
# 988
# Request returned status code 200
# 989
# Request returned status code 200
# 990
# Request returned status code 200
# 991
# Request returned status code 200
# 992
# Request returned status code 200
# 993
# Request returned status code 200
# 994
# Request returned status code 200
# 995
# Request returned status code 200
# 996
# Request returned status code 200
# 997
# Request returned status code 200
# 998
# Request returned status code 200
# 999
# Request returned status code 200
# 1000
# Request returned status code 200
# 1001
# Request returned status code 200
# 1002
# Request returned status code 200
# 1003
# Request returned status code 200
# 1004
# Request returned status code 200
# 1005
# Request returned status code 200
# 1006
# Request returned status code 200
# 1007
# Request returned status code 200
# 1008
# Request returned status code 200
# 1009
# Request returned status code 200
# 1010
# Request returned status code 200
# 1011
# Request returned status code 200
# 1012
# Request returned status code 200
# 1013
# Request returned status code 200
# 1014
# Request returned status code 200
# 1015
# Request returned status code 200
# 1016
# Request returned status code 200
# 1017
# Request returned status code 200
# 1018
# Request returned status code 200
# 1019
# Request returned status code 200
# 1020
# Request returned status code 200
# 1021
# Request returned status code 200
# 1022
# Request returned status code 200
# 1023
# Request returned status code 200
# 1024
# Request returned status code 200
# 1025
# Request returned status code 200
# 1026
# Request returned status code 200
# 1027
# Request returned status code 200
# 1028
# Request returned status code 200
# 1029
# Request returned status code 200
# 1030
# Request returned status code 200
# 1031
# Request returned status code 200
# 1032
# Request returned status code 200
# 1033
# Request returned status code 200
# 1034
# Request returned status code 200
# 1035
# Request returned status code 200
# 1036
# Request returned status code 200
# 1037
# Request returned status code 200
# 1038
# Request returned status code 200
# 1039
# Request returned status code 200
# 1040
# Request returned status code 200
# 1041
# Request returned status code 200
# 1042
# Request returned status code 200
# 1043
# Request returned status code 200
# 1044
# Request returned status code 200
# 1045
# Request returned status code 200
# 1046
# Request returned status code 200
# 1047
# Request returned status code 200
# 1048
# Request returned status code 200
# 1049
# Request returned status code 200
# 1050
# Request returned status code 200
# 1051
# Request returned status code 200
# 1052
# Request returned status code 200
# 1053
# Request returned status code 200
# 1054
# Request returned status code 200
# 1055
# Request returned status code 200
# 1056
# Request returned status code 200
# 1057
# Request returned status code 200
# 1058
# Request returned status code 200
# 1059
# Request returned status code 200
# 1060
# Request returned status code 200
# 1061
# Request returned status code 200
# 1062
# Request returned status code 200
# 1063
# Request returned status code 200
# 1064
# Request returned status code 200
# 1065
# Request returned status code 200
# 1066
# Request returned status code 200
# 1067
# Request returned status code 200
# 1068
# Request returned status code 200
# 1069
# Request returned status code 200
# 1070
# Request returned status code 200
# 1071
# Request returned status code 200
# 1072
# Request returned status code 200
# 1073
# Request returned status code 200
# 1074
# Request returned status code 200
# 1075
# Request returned status code 200
# 1076
# Request returned status code 200
# 1077
# Request returned status code 200
# 1078
# Request returned status code 200
# 1079
# Request returned status code 200
# 1080
# Request returned status code 200
# 1081
# Request returned status code 200
# 1082
# Request returned status code 200
# 1083
# Request returned status code 200
# 1084
# Request returned status code 200
# 1085
# Request returned status code 200
# 1086
# Request returned status code 200
# 1087
# Request returned status code 200
# 1088
# Request returned status code 200
# 1089
# Request returned status code 200
# 1090
# Request returned status code 200
# 1091
# Request returned status code 200
# 1092
# Request returned status code 200
# 1093
# Request returned status code 200
# 1094
# Request returned status code 200
# 1095
# Request returned status code 200
# 1096
# Request returned status code 200
# 1097
# Request returned status code 200
# 1098
# Request returned status code 200
# 1099
# Request returned status code 200
# 1100
# Request returned status code 200
# 1101
# Request returned status code 200
# 1102
# Request returned status code 200
# 1103
# Request returned status code 200
# 1104
# Request returned status code 200
# 1105
# Request returned status code 200
# 1106
# Request returned status code 200
# 1107
# Request returned status code 200
# 1108
# Request returned status code 200
# 1109
# Request returned status code 200
# 1110
# Request returned status code 200
# 1111
# Request returned status code 200
# 1112
# Request returned status code 200
# 1113
# Request returned status code 200
# 1114
# Request returned status code 200
# 1115
# Request returned status code 200
# 1116
# Request returned status code 200
# 1117
# Request returned status code 200
# 1118
# Request returned status code 200
# 1119
# Request returned status code 200
# 1120
# Request returned status code 200
# 1121
# Request returned status code 200
# 1122
# Request returned status code 200
# 1123
# Request returned status code 200
# 1124
# Request returned status code 200
# 1125
# Request returned status code 200
# 1126
# Request returned status code 200
# 1127
# Request returned status code 200
# 1128
# Request returned status code 200
# 1129
# Request returned status code 200
# 1130
# Request returned status code 200
# 1131
# Request returned status code 200
# 1132
# Request returned status code 200
# 1133
# Request returned status code 200
# 1134
# Request returned status code 200
# 1135
# Request returned status code 200
# 1136
# Request returned status code 200
# 1137
# Request returned status code 200
# 1138
# Request returned status code 200
# 1139
# Request returned status code 200
# 1140
# Request returned status code 200
# 1141
# Request returned status code 200
# 1142
# Request returned status code 200
# 1143
# Request returned status code 200
# 1144
# Request returned status code 200
# 1145
# Request returned status code 200
# 1146
# Request returned status code 200
# 1147
# Request returned status code 200
# 1148
# Request returned status code 200
# 1149
# Request returned status code 200
# 1150
# Request returned status code 200
# 1151
# Request returned status code 200
# 1152
# Request returned status code 200
# 1153
# Request returned status code 200
# 1154
# Request returned status code 200
# 1155
# Request returned status code 200
# 1156
# Request returned status code 200
# 1157
# Request returned status code 200
# 1158
# Request returned status code 200
# 1159
# Request returned status code 200
# 1160
# Request returned status code 200
# 1161
# Request returned status code 200
# 1162
# Request returned status code 200
# 1163
# Request returned status code 200
# 1164
# Request returned status code 200
# 1165
# Request returned status code 200
# 1166
# Request returned status code 200
# 1167
# Request returned status code 200
# 1168
# Request returned status code 200
# 1169
# Request returned status code 200
# 1170
# Request returned status code 200
# 1171
# Request returned status code 200
# 1172
# Request returned status code 200
# 1173
# Request returned status code 200
# 1174
# Request returned status code 200
# 1175
# Request returned status code 200
# 1176
# Request returned status code 200
# 1177
# Request returned status code 200
# 1178
# Request returned status code 200
# 1179
# Request returned status code 200
# 1180
# Request returned status code 200
# 1181
# Request returned status code 200
# 1182
# Request returned status code 200
# 1183
# Request returned status code 200
# 1184
# Request returned status code 200
# 1185
# Request returned status code 200
# 1186
# Request returned status code 200
# 1187
# Request returned status code 200
# 1188
# Request returned status code 200
# 1189
# Request returned status code 200
# 1190
# Request returned status code 200
# 1191
# Request returned status code 200
# 1192
# Request returned status code 200
# 1193
# Request returned status code 200
# 1194
# Request returned status code 200
# 1195
# Request returned status code 200
# 1196
# Request returned status code 200
# 1197
# Request returned status code 200
# 1198
# Request returned status code 200
# 1199
# Request returned status code 200
# 1200
# Request returned status code 200
# 1201
# Request returned status code 200
# 1202
# Request returned status code 200
# 1203
# Request returned status code 200
# 1204
# Request returned status code 200
# 1205
# Request returned status code 200
# 1206
# Request returned status code 200
# 1207
# Request returned status code 200
# 1208
# Request returned status code 200
# 1209
# Request returned status code 200
# 1210
# Request returned status code 200
# 1211
# Request returned status code 200
# 1212
# Request returned status code 200
# 1213
# Request returned status code 200
# 1214
# Request returned status code 200
# 1215
# Request returned status code 200
# 1216
# Request returned status code 200
# 1217
# Request returned status code 200
# 1218
# Request returned status code 200
# 1219
# Request returned status code 200
# 1220
# Request returned status code 200
# 1221
# Request returned status code 200
# 1222
# Request returned status code 200
# 1223
# Request returned status code 200
# 1224
# Request returned status code 200
# 1225
# Request returned status code 200
# 1226
# Request returned status code 200
# 1227
# Request returned status code 200
# 1228
# Request returned status code 200
# 1229
# Request returned status code 200
# 1230
# Request returned status code 200
# 1231
# Request returned status code 200
# 1232
# Request returned status code 200
# 1233
# Request returned status code 200
# 1234
# Request returned status code 200
# 1235
# Request returned status code 200
# 1236
# Request returned status code 200
# 1237
# Request returned status code 200
# 1238
# Request returned status code 200
# 1239
# Request returned status code 200
# 1240
# Request returned status code 200
# 1241
# Request returned status code 200
# 1242
# Request returned status code 200
# 1243
# Request returned status code 200
# 1244
# Request returned status code 200
# 1245
# Request returned status code 200
# 1246
# Request returned status code 200
# 1247
# Request returned status code 200
# 1248
# Request returned status code 200
# 1249
# Request returned status code 200
# 1250
# Request returned status code 200
# 1251
# Request returned status code 200
# 1252
# Request returned status code 200
# 1253
# Request returned status code 200
# 1254
# Request returned status code 200
# 1255
# Request returned status code 200
# 1256
# Request returned status code 200
# 1257
# Request returned status code 200
# 1258
# Request returned status code 200
# 1259
# Request returned status code 200
# 1260
# Request returned status code 200
# 1261
# Request returned status code 200
# 1262
# Request returned status code 200
# 1263
# Request returned status code 200
# 1264
# Request returned status code 200
# 1265
# Request returned status code 200
# 1266
# Request returned status code 200
# 1267
# Request returned status code 200
# 1268
# Request returned status code 200
# 1269
# Request returned status code 200
# 1270
# Request returned status code 200
# 1271
# Request returned status code 200
# 1272
# Request returned status code 200
# 1273
# Request returned status code 200
# 1274
# Request returned status code 200
# 1275
# Request returned status code 200
# 1276
# Request returned status code 200
# 1277
# Request returned status code 200
# 1278
# Request returned status code 200
# 1279
# Request returned status code 200
# 1280
# Request returned status code 200
# 1281
# Request returned status code 200
# 1282
# Request returned status code 200
# 1283
# Request returned status code 200
# 1284
# Request returned status code 200
# 1285
# Request returned status code 200
# 1286
# Request returned status code 200
# 1287
# Request returned status code 200
# 1288
# Request returned status code 200
# 1289
# Request returned status code 200
# 1290
# Request returned status code 200
# 1291
# Request returned status code 200
# 1292
# ...
# 4374
# Request returned status code 200
# 4375
# Request returned status code 200
# 4376
# Request returned status code 200
# 4377
# Request returned status code 200
# 4378
# Request returned status code 200
# 4379
# Request returned status code 200
# 4380
# Request returned status code 200
# 4381
# Request returned status code 200
# 4382
# Request returned status code 200
# 4383
# Request returned status code 200
# 4384
# Request returned status code 200
# 4385
# Request returned status code 200
# 4386
# Request returned status code 200
# 4387
# Request returned status code 200
# 4388
# Request returned status code 200
# 4389
# Request returned status code 200
# 4390
# Request returned status code 200
# 4391
# Request returned status code 200
# 4392
# Request returned status code 200
# 4393
# Request returned status code 200
# 4394
# Request returned status code 200
# 4395
# Request returned status code 200
# 4396
# Request returned status code 200
# 4397
# Request returned status code 200
# 4398
# Request returned status code 200
# 4399
# Request returned status code 200
# 4400
# Request returned status code 200
# 4401
# Request returned status code 200
# 4402
# Request returned status code 200
# 4403
# Request returned status code 200
# 4404
# Request returned status code 200
# 4405
# Request returned status code 200
# 4406
# Request returned status code 200
# 4407
# Request returned status code 200
# 4408
# Request returned status code 200
# 4409
# Request returned status code 200
# 4410
# Request returned status code 200
# 4411
# Request returned status code 200
# 4412
# Request returned status code 200
# 4413
# Request returned status code 200
# 4414
# Request returned status code 200
# 4415
# Request returned status code 200
# 4416
# Request returned status code 200
# 4417
# Request returned status code 200
# 4418
# Request returned status code 200
# 4419
# Request returned status code 200
# 4420
# Request returned status code 200
# 4421
# Request returned status code 200
# 4422
# Request returned status code 200
# 4423
# Request returned status code 200
# 4424
# Request returned status code 200
# 4425
# Request returned status code 200
# 4426
# Request returned status code 200
# 4427
# Request returned status code 200
# 4428
# Request returned status code 200
# 4429
# Request returned status code 200
# 4430
# Request returned status code 200
# 4431
# Request returned status code 200
# 4432
# Request returned status code 200
# 4433
# Request returned status code 200
# 4434
# Request returned status code 200
# 4435
# Request returned status code 200
# 4436
# Request returned status code 200
# 4437
# Request returned status code 200
# 4438
# Request returned status code 200
# 4439
# Request returned status code 200
# 4440
# Request returned status code 200
# 4441
# Request returned status code 200
# 4442
# Request returned status code 200
# 4443
# Request returned status code 200
# 4444
# Request returned status code 200
# 4445
# Request returned status code 200
# 4446
# Request returned status code 200
# 4447
# Request returned status code 200
# 4448
# Request returned status code 200
# 4449
# Request returned status code 200
# 4450
# Request returned status code 200
# 4451
# Request returned status code 200
# 4452
# Request returned status code 200
# 4453
# Request returned status code 200
# 4454
# Request returned status code 200
# 4455
# Request returned status code 200
# 4456
# Request returned status code 200
# 4457
# Request returned status code 200
# 4458
# Request returned status code 200
# 4459
# Request returned status code 200
# 4460
# Request returned status code 200
# 4461
# Request returned status code 200
# 4462
# Request returned status code 200
# 4463
# Request returned status code 200
# 4464
# Request returned status code 200
# 4465
# Request returned status code 200
# 4466
# Request returned status code 200
# 4467
# Request returned status code 200
# 4468
# Request returned status code 200
# 4469
# Request returned status code 200
# 4470
# Request returned status code 200
# 4471
# Request returned status code 200
# 4472
# Request returned status code 200
# 4473
# Request returned status code 200
# 4474
# Request returned status code 200
# 4475
# Request returned status code 200
# 4476
# Request returned status code 200
# 4477
# Request returned status code 200
# 4478
# Request returned status code 200
# 4479
# Request returned status code 200
# 4480
# Request returned status code 200
# 4481
# Request returned status code 200
# 4482
# Request returned status code 200
# 4483
# Request returned status code 200
# 4484
# Request returned status code 200
# 4485
# Request returned status code 200
# 4486
# Request returned status code 200
# 4487
# Request returned status code 200
# 4488
# Request returned status code 200
# 4489
# Request returned status code 200
# 4490
# Request returned status code 200
# 4491
# Request returned status code 200
# 4492
# Request returned status code 200
# 4493
# Request returned status code 200
# 4494
# Request returned status code 200
# 4495
# Request returned status code 200
# 4496
# Request returned status code 200
# 4497
# Request returned status code 200
# 4498
# Request returned status code 200
# 4499
# Request returned status code 200
# 4500
# Request returned status code 200
# 4501
# Request returned status code 200
# 4502
# Request returned status code 200
# 4503
# Request returned status code 200
# 4504
# Request returned status code 200
# 4505
# Request returned status code 200
# 4506
# Request returned status code 200
# 4507
# Request returned status code 200
# 4508
# Request returned status code 200
# 4509
# Request returned status code 200
# 4510
# Request returned status code 200
# 4511
# Request returned status code 200
# 4512
# Request returned status code 200
# 4513
# Request returned status code 200
# 4514
# Request returned status code 200
# 4515
# Request returned status code 200
# 4516
# Request returned status code 200
# 4517
# Request returned status code 200
# 4518
# Request returned status code 200
# 4519
# Request returned status code 200
# 4520
# Request returned status code 200
# 4521
# Request returned status code 200
# 4522
# Request returned status code 200
# 4523
# Request returned status code 200
# 4524
# Request returned status code 200
# 4525
# Request returned status code 200
# 4526
# Request returned status code 200
# 4527
# Request returned status code 200
# 4528
# Request returned status code 200
# 4529
# Request returned status code 200
# 4530
# Request returned status code 200
# 4531
# Request returned status code 200
# 4532
# Request returned status code 200
# 4533
# Request returned status code 200
# 4534
# Request returned status code 200
# 4535
# Request returned status code 200
# 4536
# Request returned status code 200
# 4537
# Request returned status code 200
# 4538
# Request returned status code 200
# 4539
# Request returned status code 200
# 4540
# Request returned status code 200
# 4541
# Request returned status code 200
# 4542
# Request returned status code 200
# 4543
# Request returned status code 200
# 4544
# Request returned status code 200
# 4545
# Request returned status code 200
# 4546
# Request returned status code 200
# 4547
# Request returned status code 200
# 4548
# Request returned status code 200
# 4549
# Request returned status code 200
# 4550
# Request returned status code 200
# 4551
# Request returned status code 200
# 4552
# Request returned status code 200
# 4553
# Request returned status code 200
# 4554
# Request returned status code 200
# 4555
# Request returned status code 200
# 4556
# Request returned status code 200
# 4557
# Request returned status code 200
# 4558
# Request returned status code 200
# 4559
# Request returned status code 200
# 4560
# Request returned status code 200
# 4561
# Request returned status code 200
# 4562
# Request returned status code 200
# 4563
# Request returned status code 200
# 4564
# Request returned status code 200
# 4565
# Request returned status code 200
# 4566
# Request returned status code 200
# 4567
# Request returned status code 200
# 4568
# Request returned status code 200
# 4569
# Request returned status code 200
# 4570
# Request returned status code 200
# 4571
# Request returned status code 200
# 4572
# Request returned status code 200
# 4573
# Request returned status code 200
# 4574
# Request returned status code 200
# 4575
# Request returned status code 200
# 4576
# Request returned status code 200
# 4577
# Request returned status code 200
# 4578
# Request returned status code 200
# 4579
# Request returned status code 200
# 4580
# Request returned status code 200
# 4581
# Request returned status code 200
# 4582
# Request returned status code 200
# 4583
# Request returned status code 200
# 4584
# Request returned status code 200
# 4585
# Request returned status code 200
# 4586
# Request returned status code 200
# 4587
# Request returned status code 200
# 4588
# Request returned status code 200
# 4589
# Request returned status code 200
# 4590
# Request returned status code 200
# 4591
# Request returned status code 200
# 4592
# Request returned status code 200
# 4593
# Request returned status code 200
# 4594
# Request returned status code 200
# 4595
# Request returned status code 200
# 4596
# Request returned status code 200
# 4597
# Request returned status code 200
# 4598
# Request returned status code 200
# 4599
# Request returned status code 200
# 4600
# Request returned status code 200
# 4601
# Request returned status code 200
# 4602
# Request returned status code 200
# 4603
# Request returned status code 200
# 4604
# Request returned status code 200
# 4605
# Request returned status code 200
# 4606
# Request returned status code 200
# 4607
# Request returned status code 200
# 4608
# Request returned status code 200
# 4609
# Request returned status code 200
# 4610
# Request returned status code 200
# 4611
# Request returned status code 200
# 4612
# Request returned status code 200
# 4613
# Request returned status code 200
# 4614
# Request returned status code 200
# 4615
# Request returned status code 200
# 4616
# Request returned status code 200
# 4617
# Request returned status code 200
# 4618
# Request returned status code 200
# 4619
# Request returned status code 200
# 4620
# Request returned status code 200
# 4621
# Request returned status code 200
# 4622
# Request returned status code 200
# 4623
# Request returned status code 200
# 4624
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# /opt/anaconda3/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7ff55139e970>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=4+SAGO+LANE&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7ff55139e970>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-19-66fbcd5d60d0> in <module>
# ----> 1 address = get_postal_codes(hdb_property)
#
# <ipython-input-18-d28dacbb0e4a> in get_postal_codes(df)
#      15         }
#      16
# ---> 17         res = requests.get(onemap_url, params=search_params, timeout=10000)
#      18         print(f"Request returned status code {res.status_code}")
#      19         res = res.json()
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=4+SAGO+LANE&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7ff55139e970>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
final_df = pd.merge(hdb_property, address, left_on='address', right_on='ADDRESS')

# %%
final_df.to_csv('addresses_w_prices.csv')

# %% [markdown]
# **MERGING HDB PRICES AND HDB ADDRESS**

# %%
import pandas as pd

prices = pd.read_csv("hdb_resale_prices.csv")
hdb_addresses = pd.read_csv("../addresses_full.csv")

# %%
prices["STANDARDISED"] = prices.apply(
    lambda x: f'BLK {x["block"]} {x["street_name"].strip()}', axis=1
)

hdb_addresses["STANDARDISED"] = hdb_addresses.apply(
    lambda x: f'BLK {x["blk_no"]} {x["street"]}', axis=1
)

# %%
df_combined = pd.merge(prices, hdb_addresses, how="left", on="STANDARDISED")

# %%
from shapely.geometry import Point
# Creating a point geometry column
df_combined['geometry'] = df_combined.apply(lambda x: Point((x.LONGITUDE, x.LATITUDE)),
                                       axis = 1)

# %%
df_combined.columns = df_combined.columns.str.upper()

# %%
df_final = df_combined.drop(['UNNAMED: 0_X', 'UNNAMED: 0_Y', 'ADDRESS_X', 'ADDRESS_Y', 'BLK_NO', 'STREET'], axis = 1)

# %%
df_final.columns
# Out:
# Index(['MONTH', 'TOWN', 'FLAT_TYPE', 'BLOCK', 'STREET_NAME', 'STOREY_RANGE',
#        'FLOOR_AREA_SQM', 'FLAT_MODEL', 'LEASE_COMMENCE_DATE',
#        'REMAINING_LEASE', 'RESALE_PRICE', 'STANDARDISED', 'MAX_FLOOR_LVL',
#        'YEAR_COMPLETED', 'RESIDENTIAL', 'COMMERCIAL', 'MARKET_HAWKER',
#        'MISCELLANEOUS', 'MULTISTOREY_CARPARK', 'PRECINCT_PAVILION',
#        'BLDG_CONTRACT_TOWN', 'TOTAL_DWELLING_UNITS', '1ROOM_SOLD',
#        '2ROOM_SOLD', '3ROOM_SOLD', '4ROOM_SOLD', '5ROOM_SOLD', 'EXEC_SOLD',
#        'MULTIGEN_SOLD', 'STUDIO_APARTMENT_SOLD', '1ROOM_RENTAL',
#        '2ROOM_RENTAL', '3ROOM_RENTAL', 'OTHER_ROOM_RENTAL', 'ADDRESS',
#        'STREET_NAME', 'BUILDING_NAME', 'POSTAL_CODE', 'LATITUDE', 'LONGITUDE',
#        'GEOMETRY'],
#       dtype='object')

# %%
df_final.to_csv('full_hdb_geometry_with_prices.csv', index=False)

# %%
check = pd.read_csv('full_hdb_geometry_with_prices.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (36) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
important_cols = ['ADDRESS', 'BLOCK', 'STREET_NAME', 'BUILDING_NAME', 'POSTAL_CODE', 'RESALE_PRICE', 'LATITUDE', 'LONGITUDE', 'GEOMETRY']
df_subset = check[important_cols]

df_subset.to_csv('hdb_with_prices.csv', index=False)

# %% [markdown]
# **COMBINING HDB WITH PLANNING AREA**

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %%
geo_df = gpd.read_file('../MP19_SZ_No_Sea/URA_MP19_SUBZONE_NO_SEA_PL.shp')

# %%
geo_df
# Out:
#      SUBZONE_NO                SUBZONE_N SUBZONE_C CA_IND       PLN_AREA_N  \
# 0             1              MARINA EAST    MESZ01      Y      MARINA EAST
# 1             5         INSTITUTION HILL    RVSZ05      Y     RIVER VALLEY
# 2             1           ROBERTSON QUAY    SRSZ01      Y  SINGAPORE RIVER
# 3             1  JURONG ISLAND AND BUKOM    WISZ01      N  WESTERN ISLANDS
# 4             2             FORT CANNING    MUSZ02      Y           MUSEUM
# ..          ...                      ...       ...    ...              ...
# 327           1            UPPER THOMSON    BSSZ01      N           BISHAN
# 328           5               SHANGRI-LA    AMSZ05      N       ANG MO KIO
# 329           4               TOWNSVILLE    AMSZ04      N       ANG MO KIO
# 330           2                MARYMOUNT    BSSZ02      N           BISHAN
# 331           6      TUAS VIEW EXTENSION    TSSZ06      N             TUAS
#
#     PLN_AREA_C           REGION_N REGION_C           INC_CRC  FMEL_UPD_D  \
# 0           ME     CENTRAL REGION       CR  4FB7E5B1B9455DE0  2019-12-23
# 1           RV     CENTRAL REGION       CR  C3C22D1EE31757BD  2019-12-23
# 2           SR     CENTRAL REGION       CR  87306ABAF4B67E2E  2019-12-23
# 3           WI        WEST REGION       WR  C87E378D3456FC35  2019-12-23
# 4           MU     CENTRAL REGION       CR  8E8F2616FFA9E019  2019-12-23
# ..         ...                ...      ...               ...         ...
# 327         BS     CENTRAL REGION       CR  716DA27F6666AB0C  2019-12-23
# 328         AM  NORTH-EAST REGION      NER  9FA8567B39D8D9D7  2019-12-23
# 329         AM  NORTH-EAST REGION      NER  F5558D84EBC2AAA7  2019-12-23
# 330         BS     CENTRAL REGION       CR  154AA8659ADDE6D7  2019-12-23
# 331         TS        WEST REGION       WR  9E88DD747862051B  2019-12-23
#
#                                               geometry
# 0    POLYGON ((33222.981 29588.127, 33222.515 29587...
# 1    POLYGON ((28481.446 30886.220, 28483.405 30886...
# 2    POLYGON ((28087.344 30540.999, 28087.540 30540...
# 3    MULTIPOLYGON (((14557.697 30447.212, 14562.889...
# 4    POLYGON ((29542.526 31041.199, 29553.718 31034...
# ..                                                 ...
# 327  POLYGON ((29036.498 38365.086, 29015.440 38293...
# 328  POLYGON ((28228.195 39216.137, 28271.551 39216...
# 329  POLYGON ((29649.875 38978.996, 29671.324 38978...
# 330  POLYGON ((29469.703 36372.102, 29466.131 36348...
# 331  MULTIPOLYGON (((4929.537 32139.355, 4502.137 3...
#
# [332 rows x 11 columns]

# %%
df_subset['GEOMETRY'] = df_subset.apply(lambda x: Point((x.LONGITUDE, x.LATITUDE)),
                                       axis = 1)
# Out:
# <ipython-input-59-8e0bc64e1258>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['GEOMETRY'] = df_subset.apply(lambda x: Point((x.LONGITUDE, x.LATITUDE)),

# %%
# Create a GeoDataFrame from the original hdb_prices DataFrame
hdb_prices_geo = gpd.GeoDataFrame(df_subset, 
                                 crs = "epsg:4326",
                                 geometry = df_subset.GEOMETRY)

# %%
# Reprojecting CRS 
geo_df_reproj = geo_df.to_crs(3857)            
hdb_prices_geo_reproj = hdb_prices_geo.to_crs(3857)

# %%
hdb_prices_geo_reproj
# Out:
#                                            ADDRESS BLOCK        STREET_NAME  \
# 0                     406 ANG MO KIO AVE 10  NIL     406  ANG MO KIO AVE 10
# 1                  108 ANG MO KIO AVE 4  UNKNOWN     108   ANG MO KIO AVE 4
# 2       602 ANG MO KIO AVE 5  YIO CHU KANG GREEN     602   ANG MO KIO AVE 5
# 3       465 ANG MO KIO AVE 10  TECK GHEE HORIZON     465  ANG MO KIO AVE 10
# 4                  601 ANG MO KIO AVE 5  UNKNOWN     601   ANG MO KIO AVE 5
# ...                                            ...   ...                ...
# 135328        713 YISHUN ST 71  CHONG PANG GREEN     713       YISHUN ST 71
# 135329                     391 YISHUN AVE 6  NIL     391       YISHUN AVE 6
# 135330          361 YISHUN RING RD  YISHUN GLORY     361     YISHUN RING RD
# 135331                     614 YISHUN ST 61  NIL     614       YISHUN ST 61
# 135332                     828 YISHUN ST 81  NIL     828       YISHUN ST 81
#
#              BUILDING_NAME POSTAL_CODE  RESALE_PRICE  LATITUDE   LONGITUDE  \
# 0                      NIL      560406      232000.0  1.362005  103.853880
# 1                  UNKNOWN      560108      250000.0  1.370966  103.838202
# 2       YIO CHU KANG GREEN      560602      262000.0  1.380709  103.835368
# 3        TECK GHEE HORIZON      560465      265000.0  1.366201  103.857201
# 4                  UNKNOWN      560601      265000.0  1.381041  103.835132
# ...                    ...         ...           ...       ...         ...
# 135328    CHONG PANG GREEN      760713      532000.0  1.427528  103.827417
# 135329                 NIL      760391      740000.0  1.429468  103.849171
# 135330        YISHUN GLORY      760361      735000.0  1.428325  103.845908
# 135331                 NIL      760614      798000.0  1.419829  103.836033
# 135332                 NIL      760828      818000.0  1.415191  103.832902
#
#                                GEOMETRY                         geometry
# 0       POINT (103.8538799 1.362004539)  POINT (11560961.027 151631.933)
# 1       POINT (103.8382019 1.370966352)  POINT (11559215.760 152629.841)
# 2        POINT (103.8353682 1.38070883)  POINT (11558900.314 153714.682)
# 3        POINT (103.857201 1.366201041)  POINT (11561330.731 152099.218)
# 4       POINT (103.8351317 1.381041348)  POINT (11558873.987 153751.708)
# ...                                 ...                              ...
# 135328  POINT (103.8274166 1.427528119)  POINT (11558015.146 158928.147)
# 135329  POINT (103.8491714 1.429467692)  POINT (11560436.880 159144.126)
# 135330  POINT (103.8459083 1.428324759)  POINT (11560073.633 159016.856)
# 135331  POINT (103.8360325 1.419829067)  POINT (11558974.264 158070.828)
# 135332   POINT (103.8329017 1.41519093)  POINT (11558625.745 157554.355)
#
# [135333 rows x 10 columns]

# %%
geo_df_reproj
# Out:
#      SUBZONE_NO                SUBZONE_N SUBZONE_C CA_IND       PLN_AREA_N  \
# 0             1              MARINA EAST    MESZ01      Y      MARINA EAST
# 1             5         INSTITUTION HILL    RVSZ05      Y     RIVER VALLEY
# 2             1           ROBERTSON QUAY    SRSZ01      Y  SINGAPORE RIVER
# 3             1  JURONG ISLAND AND BUKOM    WISZ01      N  WESTERN ISLANDS
# 4             2             FORT CANNING    MUSZ02      Y           MUSEUM
# ..          ...                      ...       ...    ...              ...
# 327           1            UPPER THOMSON    BSSZ01      N           BISHAN
# 328           5               SHANGRI-LA    AMSZ05      N       ANG MO KIO
# 329           4               TOWNSVILLE    AMSZ04      N       ANG MO KIO
# 330           2                MARYMOUNT    BSSZ02      N           BISHAN
# 331           6      TUAS VIEW EXTENSION    TSSZ06      N             TUAS
#
#     PLN_AREA_C           REGION_N REGION_C           INC_CRC  FMEL_UPD_D  \
# 0           ME     CENTRAL REGION       CR  4FB7E5B1B9455DE0  2019-12-23
# 1           RV     CENTRAL REGION       CR  C3C22D1EE31757BD  2019-12-23
# 2           SR     CENTRAL REGION       CR  87306ABAF4B67E2E  2019-12-23
# 3           WI        WEST REGION       WR  C87E378D3456FC35  2019-12-23
# 4           MU     CENTRAL REGION       CR  8E8F2616FFA9E019  2019-12-23
# ..         ...                ...      ...               ...         ...
# 327         BS     CENTRAL REGION       CR  716DA27F6666AB0C  2019-12-23
# 328         AM  NORTH-EAST REGION      NER  9FA8567B39D8D9D7  2019-12-23
# 329         AM  NORTH-EAST REGION      NER  F5558D84EBC2AAA7  2019-12-23
# 330         BS     CENTRAL REGION       CR  154AA8659ADDE6D7  2019-12-23
# 331         TS        WEST REGION       WR  9E88DD747862051B  2019-12-23
#
#                                               geometry
# 0    POLYGON ((11563896.435 142930.445, 11563895.96...
# 1    POLYGON ((11559153.720 144237.660, 11559155.68...
# 2    POLYGON ((11558759.518 143890.025, 11558759.71...
# 3    MULTIPOLYGON (((11545226.465 143795.261, 11545...
# 4    POLYGON ((11560215.071 144393.718, 11560226.26...
# ..                                                 ...
# 327  POLYGON ((11559708.941 151768.914, 11559687.87...
# 328  POLYGON ((11558900.412 152625.941, 11558943.78...
# 329  POLYGON ((11560322.494 152387.131, 11560343.95...
# 330  POLYGON ((11560142.257 149761.947, 11560138.68...
# 331  MULTIPOLYGON (((11535595.776 145498.600, 11535...
#
# [332 rows x 11 columns]

# %%
joined_gdf = gpd.sjoin(hdb_prices_geo_reproj, 
                       geo_df_reproj, 
                       how = 'left')

# %%
joined_gdf.columns
# Out:
# Index(['ADDRESS', 'BLOCK', 'STREET_NAME', 'BUILDING_NAME', 'POSTAL_CODE',
#        'RESALE_PRICE', 'LATITUDE', 'LONGITUDE', 'GEOMETRY', 'geometry',
#        'index_right', 'SUBZONE_NO', 'SUBZONE_N', 'SUBZONE_C', 'CA_IND',
#        'PLN_AREA_N', 'PLN_AREA_C', 'REGION_N', 'REGION_C', 'INC_CRC',
#        'FMEL_UPD_D'],
#       dtype='object')

# %%
gdf_subset = joined_gdf.drop(columns='GEOMETRY')

# %%
gdf_subset.head()
# Out:
#                                       ADDRESS BLOCK        STREET_NAME  \
# 0                406 ANG MO KIO AVE 10  NIL     406  ANG MO KIO AVE 10
# 1             108 ANG MO KIO AVE 4  UNKNOWN     108   ANG MO KIO AVE 4
# 2  602 ANG MO KIO AVE 5  YIO CHU KANG GREEN     602   ANG MO KIO AVE 5
# 3  465 ANG MO KIO AVE 10  TECK GHEE HORIZON     465  ANG MO KIO AVE 10
# 4             601 ANG MO KIO AVE 5  UNKNOWN     601   ANG MO KIO AVE 5
#
#         BUILDING_NAME POSTAL_CODE  RESALE_PRICE  LATITUDE   LONGITUDE  \
# 0                 NIL      560406      232000.0  1.362005  103.853880
# 1             UNKNOWN      560108      250000.0  1.370966  103.838202
# 2  YIO CHU KANG GREEN      560602      262000.0  1.380709  103.835368
# 3   TECK GHEE HORIZON      560465      265000.0  1.366201  103.857201
# 4             UNKNOWN      560601      265000.0  1.381041  103.835132
#
#                           geometry  index_right  SUBZONE_NO  \
# 0  POINT (11560961.027 151631.933)          162           3
# 1  POINT (11559215.760 152629.841)          171           6
# 2  POINT (11558900.314 153714.682)          241           9
# 3  POINT (11561330.731 152099.218)          162           3
# 4  POINT (11558873.987 153751.708)          241           9
#
#            SUBZONE_N SUBZONE_C CA_IND  PLN_AREA_N PLN_AREA_C  \
# 0         CHONG BOON    AMSZ03      N  ANG MO KIO         AM
# 1        KEBUN BAHRU    AMSZ06      N  ANG MO KIO         AM
# 2  YIO CHU KANG WEST    AMSZ09      N  ANG MO KIO         AM
# 3         CHONG BOON    AMSZ03      N  ANG MO KIO         AM
# 4  YIO CHU KANG WEST    AMSZ09      N  ANG MO KIO         AM
#
#             REGION_N REGION_C           INC_CRC  FMEL_UPD_D
# 0  NORTH-EAST REGION      NER  94B98B182E1B853F  2019-12-23
# 1  NORTH-EAST REGION      NER  60BFB1E98CF343F9  2019-12-23
# 2  NORTH-EAST REGION      NER  34215498CFFEE6DF  2019-12-23
# 3  NORTH-EAST REGION      NER  94B98B182E1B853F  2019-12-23
# 4  NORTH-EAST REGION      NER  34215498CFFEE6DF  2019-12-23

# %%
gdf_subset.to_file('hdb_prices_with_planning_area.shp')
# Out:
# <ipython-input-69-551b827722ab>:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_subset.to_file('hdb_prices_with_planning_area.shp')
