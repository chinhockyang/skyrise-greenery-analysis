# %% [markdown]
# # Retrieve Data From Datamall
#
# Data Retrieved from LTA Datamall:
# - Bus Stop
# - Bus Services
# - Bus Routes
# - Passenger Volume (Bus Stops)
# - Passenger Volume (Origin Destination Bus Stops)
# - Passenger Volume (Train Stations)
# - Passenger Volume (Origin Destination Train Stations)
#
# Some APIs such as GeospatialWholeIsland (to retrieve Cycling paths) do not work, have to download from LTA's website manually

# %% [markdown]
# ### Loading Libraries and API Configurations

# %%
# General Data  Tools
import pandas as pd
import numpy as np
import os

# Utilities
from utility import retrieve_from_datamall

# Load API Token
from dotenv import load_dotenv
load_dotenv()
datamall_token = os.getenv('datamall_token')

# %% [markdown]
# ### Bus Stop Data

# %%
df_bus_stops = retrieve_from_datamall(datamall_token, 'BusStops')

# %%
df_bus_stops
# Out:
#    BusStopCode           RoadName             Description  Latitude  \
# 0        01012        Victoria St     Hotel Grand Pacific  1.296848
# 1        01013        Victoria St         St. Joseph's Ch  1.297710
# 2        01019        Victoria St         Bras Basah Cplx  1.296990
# 3        01029      Nth Bridge Rd            Opp Natl Lib  1.296673
# 4        01039      Nth Bridge Rd              Bugis Cube  1.298208
# ..         ...                ...                     ...       ...
# 63       99139  Changi Village Rd                   Blk 5  1.388195
# 64       99161          Nicoll Dr   Bef Changi Beach CP 3  1.390262
# 65       99171          Nicoll Dr       Changi Beach CP 2  1.391128
# 66       99181      Telok Paku Rd  Bef S'pore Aviation Ac  1.387754
# 67       99189      Telok Paku Rd      S'pore Aviation Ac  1.388414
#
#      Longitude
# 0   103.852536
# 1   103.853225
# 2   103.853022
# 3   103.854414
# 4   103.855491
# ..         ...
# 63  103.987234
# 64  103.992957
# 65  103.991021
# 66  103.988503
# 67  103.989716
#
# [5068 rows x 5 columns]

# %%
df_bus_stops[df_bus_stops.duplicated()]
# Out:
# Empty DataFrame
# Columns: [BusStopCode, RoadName, Description, Latitude, Longitude]
# Index: []

# %%
df_bus_stops.dtypes
# Out:
# BusStopCode     object
# RoadName        object
# Description     object
# Latitude       float64
# Longitude      float64
# dtype: object

# %%
print(df_bus_stops.shape)
print(df_bus_stops.isnull().sum())
# Out:
# (5068, 5)
# BusStopCode    0
# RoadName       0
# Description    0
# Latitude       0
# Longitude      0
# dtype: int64

# %%
df_bus_stops.to_csv("../data/bus_stops.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Bus Services Data

# %%
df_bus_services = retrieve_from_datamall(datamall_token, 'BusServices')

# %%
df_bus_services[df_bus_services.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ServiceNo, Operator, Direction, Category, OriginCode, DestinationCode, AM_Peak_Freq, AM_Offpeak_Freq, PM_Peak_Freq, PM_Offpeak_Freq, LoopDesc]
# Index: []

# %%
df_bus_services
# Out:
#     ServiceNo Operator  Direction Category OriginCode DestinationCode  \
# 0         118      GAS          1    TRUNK      65009           97009
# 1         118      GAS          2    TRUNK      97009           65009
# 2        118A      GAS          1    TRUNK      65199           96119
# 3        118B      GAS          1    TRUNK      96111           65191
# 4         119      GAS          1    TRUNK      65009           65009
# ..        ...      ...        ...      ...        ...             ...
# 195       981      TTS          2    TRUNK      47121           58009
# 196       98A      TTS          1    TRUNK      28091           21179
# 197       98B      TTS          1    TRUNK      28501           21099
# 198       98M      TTS          1    TRUNK      28009           28009
# 199       990      TTS          1    TRUNK      43009           43009
#
#     AM_Peak_Freq AM_Offpeak_Freq PM_Peak_Freq PM_Offpeak_Freq  \
# 0           5-08            8-12         8-10           09-14
# 1          10-10            8-11         4-08            9-12
# 2          14-16               -            -               -
# 3              -               -        24-57               -
# 4          09-13           12-18        12-15           15-17
# ..           ...             ...          ...             ...
# 195            -               -        10-10           10-10
# 196            -               -        08-16           07-19
# 197        06-51           10-10            -               -
# 198            -           17-18            -           12-17
# 199        11-11           12-15        11-13           11-14
#
#               LoopDesc
# 0
# 1
# 2
# 3
# 4        Hougang St 21
# ..                 ...
# 195
# 196
# 197
# 198     Corporation Rd
# 199  Jurong Gateway Rd
#
# [700 rows x 11 columns]

# %%
df_bus_services.dtypes
# Out:
# ServiceNo          object
# Operator           object
# Direction           int64
# Category           object
# OriginCode         object
# DestinationCode    object
# AM_Peak_Freq       object
# AM_Offpeak_Freq    object
# PM_Peak_Freq       object
# PM_Offpeak_Freq    object
# LoopDesc           object
# dtype: object

# %%
print(df_bus_services.shape)
print(df_bus_services.isnull().sum())
# Out:
# (700, 11)
# ServiceNo          0
# Operator           0
# Direction          0
# Category           0
# OriginCode         0
# DestinationCode    0
# AM_Peak_Freq       0
# AM_Offpeak_Freq    0
# PM_Peak_Freq       0
# PM_Offpeak_Freq    0
# LoopDesc           0
# dtype: int64

# %%
df_bus_services.to_csv("../data/bus_services.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Bus Routes Data

# %%
df_bus_routes = retrieve_from_datamall(datamall_token, 'BusRoutes')

# %%
df_bus_routes[df_bus_routes.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ServiceNo, Operator, Direction, StopSequence, BusStopCode, Distance, WD_FirstBus, WD_LastBus, SAT_FirstBus, SAT_LastBus, SUN_FirstBus, SUN_LastBus]
# Index: []

# %%
df_bus_routes
# Out:
#    ServiceNo Operator  Direction  StopSequence BusStopCode  Distance  \
# 0         10     SBST          1             1       75009       0.0
# 1         10     SBST          1             2       76059       0.6
# 2         10     SBST          1             3       76069       1.1
# 3         10     SBST          1             4       96289       2.3
# 4         10     SBST          1             5       96109       2.7
# ..       ...      ...        ...           ...         ...       ...
# 36        9A     SBST          1            17       76101       6.9
# 37        9A     SBST          1            18       76031       7.1
# 38        9A     SBST          1            19       76231       7.5
# 39        9A     SBST          1            20       76241       7.8
# 40        9A     SBST          1            21       98011       8.4
#
#    WD_FirstBus WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus SUN_LastBus
# 0         0500       2300         0500        2300         0500        2300
# 1         0502       2302         0502        2302         0502        2302
# 2         0504       2304         0504        2304         0503        2304
# 3         0508       2308         0508        2309         0507        2308
# 4         0509       2310         0509        2311         0508        2309
# ..         ...        ...          ...         ...          ...         ...
# 36        1851       2026            -           -            -           -
# 37        1852       2027            -           -            -           -
# 38        1854       2029            -           -            -           -
# 39        1856       2030            -           -            -           -
# 40        1859       2033            -           -            -           -
#
# [25041 rows x 12 columns]

# %%
df_bus_routes.dtypes
# Out:
# ServiceNo        object
# Operator         object
# Direction         int64
# StopSequence      int64
# BusStopCode      object
# Distance        float64
# WD_FirstBus      object
# WD_LastBus       object
# SAT_FirstBus     object
# SAT_LastBus      object
# SUN_FirstBus     object
# SUN_LastBus      object
# dtype: object

# %%
print(df_bus_routes.shape)
print(df_bus_routes.isnull().sum())
# Out:
# (25041, 12)
# ServiceNo       0
# Operator        0
# Direction       0
# StopSequence    0
# BusStopCode     0
# Distance        0
# WD_FirstBus     0
# WD_LastBus      0
# SAT_FirstBus    0
# SAT_LastBus     0
# SUN_FirstBus    0
# SUN_LastBus     0
# dtype: int64

# %%
df_bus_routes.to_csv("../data/bus_routes.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Passenger Volume - Bus Stops

# %%
df_pv_bus_stops = retrieve_from_datamall(datamall_token, 'PV/Bus', payload={"Date": "202209"})

# URL Valid for 3 min only
df_pv_bus_stops.values

# %% [markdown]
# ### Passenger Volume - Origin Destination Bus Stops

# %%
df_pv_od_bus_stops = retrieve_from_datamall(datamall_token, 'PV/ODBus', payload={"Date": "202209"})

# URL Valid for 3 min only
df_pv_od_bus_stops.values

# %% [markdown]
# ### Passenger Volume - Train

# %%
df_pv_train = retrieve_from_datamall(datamall_token, 'PV/Train', payload={"Date": "202209"})

# URL Valid for 3 min only
df_pv_train.values

# %% [markdown]
# ### Passenger Volume - Origin Destination Train

# %%
df_pv_od_train = retrieve_from_datamall(datamall_token, 'PV/ODTrain', payload={"Date": "202209"})


# URL Valid for 3 min only
df_pv_od_train.values
