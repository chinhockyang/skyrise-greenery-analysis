# %% [markdown]
# # Convert MSS Station Locations into Shapefile
#
# Url of PDF with Meteorological Service Stations Information: ```http://www.weather.gov.sg/wp-content/uploads/2022/06/Station_Records.pdf```

# %% [markdown]
# ### Loading Libraries

# %%
import pandas as pd
import geopandas as gpd
import tabula
from utility import export_df_to_shapefile

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Use Tabula to Convert Tables in PDF into DataFrame

# %%
# 3 Pages in Total in PDF
all_tables = tabula.read_pdf("../data/Station_Records.pdf", pages="1-3")

# %% [markdown]
# #### Page 1

# %%
page_1 = all_tables[0]

# %%
page_1
# Out:
#           Unnamed: 0           Position    Period of Daily  \
# 0                NaN                NaN       Rain Records
# 1                NaN                NaN                NaN
# 2            Station  Lat.(N) Long. (E)                NaN
# 3         Paya Lebar    1.3524 103.9007   Jan 1980-current
# 4             Tengah    1.3858 103.7114   Jan 1980-current
# 5             Changi    1.3678 103.9826   Jan 1981-current
# 6            Seletar    1.4166 103.8654   Jan 1980-current
# 7           Tai Seng    1.3399 103.8878   Jan 1980-current
# 8      Jurong (West)    1.3455 103.6806   Jan 1980-current
# 9         Ang Mo Kio    1.3764 103.8492   Sep 2009-current
# 10          Clementi    1.3337 103.7768   Jan 1980-current
# 11         Admiralty    1.4439 103.7854   Jan 2009-current
# 12    Sentosa Island    1.2500 103.8279    Jan1980-current
# 13         Sembawang    1.4252 103.8202   Jan 1991-current
# 14   Boon Lay (East)    1.3302 103.7205  Dec 2009-Jan 2016
# 15    Semakau Island    1.1890 103.7680   Jan 2009-current
# 16        Pulau Ubin    1.4168 103.9673   Jan 2009-current
# 17        East Coast                NaN                NaN
# 18           Parkway    1.3134 103.9619   Jun 2009-current
# 19    Marina Barrage    1.2799 103.8703   Jul 2010-current
# 20            Newton    1.3106 103.8365   Oct 2009-current
# 21        Tuas South    1.2938 103.6184   Apr 2011-current
# 22     Pasir Panjang    1.2810 103.7540   Mar 2010-current
# 23     Jurong Island    1.2542 103.6741   Aug 2011-current
# 24     Choa Chu Kang                NaN                NaN
# 25           (South)    1.3729 103.7224   Apr 2011-current
# 26            Khatib    1.4173 103.8249  Oct 2010-Sep 2021
# 27        Macritchie                NaN                NaN
# 28         Reservoir    1.3417 103.8338   Jan 1980-current
# 29      Lower Peirce                NaN                NaN
# 30         Reservoir    1.3701 103.8271   Jan 2010-current
# 31  Pasir Ris (West)    1.3863 103.9412   Jan 1980-current
# 32     Kampong Bahru    1.2745 103.8280  Jan 1980-Oct 2016
# 33       Jurong Pier    1.3081 103.7100   Jan 1980-current
#
#              Period of     Period of Mean  Period of Max and  \
# 0   30,60,120-Min Rain        Temperature    Min Temperature
# 1              Records                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                    -   Sep 2017-current   Jan 1981-current
# 4                    -   Aug 1986-current   Jan 1985-current
# 5     Jan 2014-current   Jan 1982-current   Jan 1982-current
# 6                    -   Aug 1986-current   Jan 1985-current
# 7     Jan 2014-current   May 2011-current   May 2011-current
# 8     Jan 2014-current   Mar 2009-current   Mar 2009-current
# 9     Jan 2014-current   Sep 2009-current   Sep 2009-current
# 10    Jan 2014-current   Apr 2010-current   Apr 2010-current
# 11    Jan 2014-current   Jan 2009-current   Jan 2009-current
# 12    Jan 2014-current   Mar 2010-current   Mar 2010-current
# 13                   -   Jan 1991-current   Jan 1991-current
# 14   Jan 2014-Jan 2016  Dec 2009-Jan 2016  Dec 2009-Jan 2016
# 15    Jan 2014-current   Jan 2009-current   Jan 2009-current
# 16    Jan 2014-current   Jan 2009-current   Jan 2009-current
# 17                 NaN                NaN                NaN
# 18    Jan 2014-current   Jun 2009-current   Jun 2009-current
# 19    Jan 2014-current   Jul 2010-current   Jul 2010-current
# 20    Jan 2014-current   Oct 2009-current   Oct 2009-current
# 21    Jan 2014-current   Apr 2011-current   Apr 2011-current
# 22    Jan 2014-current   Mar 2010-current   Mar 2010-current
# 23    Jan 2014-current   Aug 2011-current   Aug 2011-current
# 24                 NaN                NaN                NaN
# 25    Jan 2014-current   Apr 2011-current   Apr 2011-current
# 26   Jan 2014-Sep 2021  Oct 2010-Sep 2021  Oct 2010-Sep 2021
# 27                 NaN                NaN                NaN
# 28    Jan 2014-current                NaN                NaN
# 29                 NaN                NaN                NaN
# 30    Jan 2014-current                NaN                NaN
# 31    Jan 2014-current                NaN                NaN
# 32   Jan 2014-Oct 2016                NaN                NaN
# 33    Jan 2014-current                NaN                NaN
#
#      Period of Mean.1      Period of Max
# 0          Wind Speed         Wind Speed
# 1                 NaN                NaN
# 2                 NaN                NaN
# 3   Jan 1981- current   Jan 2010-current
# 4    Jan 1985-current   Jan 2010-current
# 5    Jan 1983-current   Jan 1983-current
# 6    Jan 1985-current   Jan 2010-current
# 7    May 2011-current   May 2011-current
# 8    Mar 2009-current   Mar 2009-current
# 9    Sep 2009-current   Sep 2009-current
# 10   Apr 2010-current   Apr 2010-current
# 11   Jan 2009-current   Jan 2009-current
# 12   Mar 2010-current   Mar 2010-current
# 13   Jan 1991-current   Jan 2010-current
# 14  Dec 2009-Jan 2016  Dec 2009-Jan 2016
# 15   Jan 2009-current   Jan 2009-current
# 16   Jan 2009-current   Jan 2009-current
# 17                NaN                NaN
# 18   Jun 2009-current   Jun 2009-current
# 19   Jul 2010-current   Jul 2010-current
# 20   Oct 2009-current   Oct 2009-current
# 21   Apr 2011-current   Apr 2011-current
# 22   Mar 2010-current   Mar 2010-current
# 23   Aug 2011-current   Aug 2011-current
# 24                NaN                NaN
# 25   Apr 2011-current   Apr 2011-current
# 26  Oct 2010-Sep 2021  Oct 2010-Sep 2021
# 27                NaN                NaN
# 28                NaN                NaN
# 29                NaN                NaN
# 30                NaN                NaN
# 31                NaN                NaN
# 32                NaN                NaN
# 33                NaN                NaN

# %% [markdown]
# Problematic Entries:
# - East Coast (index 17) --> use index 18's Coordinates instead [actual name: East Coast Parkway]
# - Choa Chu Kang (index 24) --> use index 25's Coordinates instead [actual name: Choa Chu Kang (South)]
# - Macritchie (index 27) --> use index 28's Coordinates instead [actual name: Macritchie]
# - Lower Peirce (index 29) --> use index 30's Coordinates instead [actual name: Lower Peirce Reservoir]
#
# Index to delete:
# - 0, 1, 2, 18, 25, 28, 30

# %%
#### Fix the Station Name and Geocordinates of Problematic Entries
page_1.loc[17, "Unnamed: 0"] = "East Coast Parkway"
page_1.loc[17, "Position"] = page_1.loc[18, "Position"]

page_1.loc[24, "Unnamed: 0"] = "Choa Chu Kang (South)"
page_1.loc[24, "Position"] = page_1.loc[25, "Position"]

page_1.loc[27, "Unnamed: 0"] = "Macritchie Reservoir"
page_1.loc[27, "Position"] = page_1.loc[28, "Position"]

page_1.loc[29, "Unnamed: 0"] = "Lower Peirce Reservoir"
page_1.loc[29, "Position"] = page_1.loc[30, "Position"]

#### Delete extra rows
page_1.drop([0, 1, 2, 18, 25, 28, 30], axis=0, inplace=True)
page_1.reset_index(drop=True, inplace=True)

#### Subset Station Name and coordinates columns and Rename Columns
page_1 = page_1[["Unnamed: 0", "Position"]].copy()
page_1.rename(columns={"Unnamed: 0" : "station", "Position": "coordinates"}, inplace=True)

# %%
page_1
# Out:
#                    station      coordinates
# 0               Paya Lebar  1.3524 103.9007
# 1                   Tengah  1.3858 103.7114
# 2                   Changi  1.3678 103.9826
# 3                  Seletar  1.4166 103.8654
# 4                 Tai Seng  1.3399 103.8878
# 5            Jurong (West)  1.3455 103.6806
# 6               Ang Mo Kio  1.3764 103.8492
# 7                 Clementi  1.3337 103.7768
# 8                Admiralty  1.4439 103.7854
# 9           Sentosa Island  1.2500 103.8279
# 10               Sembawang  1.4252 103.8202
# 11         Boon Lay (East)  1.3302 103.7205
# 12          Semakau Island  1.1890 103.7680
# 13              Pulau Ubin  1.4168 103.9673
# 14      East Coast Parkway  1.3134 103.9619
# 15          Marina Barrage  1.2799 103.8703
# 16                  Newton  1.3106 103.8365
# 17              Tuas South  1.2938 103.6184
# 18           Pasir Panjang  1.2810 103.7540
# 19           Jurong Island  1.2542 103.6741
# 20   Choa Chu Kang (South)  1.3729 103.7224
# 21                  Khatib  1.4173 103.8249
# 22    Macritchie Reservoir  1.3417 103.8338
# 23  Lower Peirce Reservoir  1.3701 103.8271
# 24        Pasir Ris (West)  1.3863 103.9412
# 25           Kampong Bahru  1.2745 103.8280
# 26             Jurong Pier  1.3081 103.7100

# %% [markdown]
# #### Page 2

# %%
page_2 = all_tables[1]

# %%
page_2
# Out:
#            Unnamed: 0           Position    Period of Daily  \
# 0                 NaN                NaN       Rain Records
# 1                 NaN                NaN                NaN
# 2             Station  Lat.(N) Long. (E)                NaN
# 3          Ulu Pandan    1.3329 103.7556   Jan 1980-current
# 4           Serangoon    1.3382 103.8657   Jan 1980-current
# 5       Jurong (East)    1.3262 103.7354  Jan 1980-Sep 2014
# 6              Mandai    1.4036 103.7898   Jan 1980-current
# 7       Upper Thomson    1.3416 103.8106  Jan 1980-Dec 2020
# 8            Buangkok    1.3837 103.8860  Jan 1980-Feb 2019
# 9     Boon Lay (West)    1.3275 103.7042  Jan 1980-Dec 2017
# 10      Bukit Panjang    1.3824 103.7603   Jan 1980-current
# 11   Kranji Reservoir    1.4387 103.7363   Jan 1980-current
# 12      Tanjong Pagar    1.2740 103.8482  Jan 1983-Nov 2015
# 13   Admiralty (West)    1.4582 103.7953  Jan 2009-Jan 2020
# 14         Queenstown    1.2937 103.8125   Jan 1980-current
# 15     Tanjong Katong    1.3070 103.8907   Jan 1980-current
# 16          Chai Chee    1.3277 103.9203   Dec 2009-current
# 17       Upper Peirce                NaN                NaN
# 18          Reservoir    1.3700 103.8050   Feb 2010-current
# 19         Kent Ridge    1.2923 103.7815   Mar 2009-current
# 20           Somerset    1.3004 103.8372   Apr 2011-current
# 21            Punggol    1.4029 103.9092   Jun 2009-current
# 22          Tuas West    1.3247 103.6351   Mar 2009-current
# 23              Simei    1.3437 103.9444   Jun 2009-current
# 24          Toa Payoh    1.3415 103.8519   Mar 2010-current
# 25               Tuas    1.3199 103.6616   Jan 2009-current
# 26        Bukit Timah    1.3191 103.8191   Mar 2009-current
# 27             Yishun    1.4301 103.8308  May 2009-Mar 2021
# 28        Buona Vista    1.2841 103.7886   Mar 2009-current
# 29  Pasir Ris Central    1.3679 103.9489   Mar 2010-current
# 30     Jurong (North)    1.3505 103.7134  Jan 2009-Dec 2018
# 31      Choa Chu Kang                NaN                NaN
# 32             (West)    1.3746 103.6938   Jan 1980-current
#
#              Period of Period of Mean Period of Max and Period of Mean.1  \
# 0   30,60,120-Min Rain    Temperature   Min Temperature       Wind Speed
# 1              Records            NaN               NaN              NaN
# 2                  NaN            NaN               NaN              NaN
# 3     Jan 2014-current            NaN               NaN              NaN
# 4     Jan 2014-current            NaN               NaN              NaN
# 5    Jan 2014-Sep 2014            NaN               NaN              NaN
# 6     Jan 2014-current            NaN               NaN              NaN
# 7    Jan 2014-Dec 2020            NaN               NaN              NaN
# 8    Jan 2014-Feb 2019            NaN               NaN              NaN
# 9    Jan 2014-Dec 2017            NaN               NaN              NaN
# 10    Jan 2014-current            NaN               NaN              NaN
# 11    Jan 2014-current            NaN               NaN              NaN
# 12   Jan 2014-Nov 2015            NaN               NaN              NaN
# 13   Jan 2014-Jan 2020            NaN               NaN              NaN
# 14    Jan 2014-current            NaN               NaN              NaN
# 15    Jan 2014-current            NaN               NaN              NaN
# 16    Jan 2014-current            NaN               NaN              NaN
# 17                 NaN            NaN               NaN              NaN
# 18    Jan 2014-current            NaN               NaN              NaN
# 19    Jan 2014-current            NaN               NaN              NaN
# 20    Jan 2014-current            NaN               NaN              NaN
# 21    Jan 2014-current            NaN               NaN              NaN
# 22    Jan 2014-current            NaN               NaN              NaN
# 23    Jan 2014-current            NaN               NaN              NaN
# 24    Jan 2014-current            NaN               NaN              NaN
# 25    Jan 2014-current            NaN               NaN              NaN
# 26    Jan 2014-current            NaN               NaN              NaN
# 27   Jan 2014-Mar 2021            NaN               NaN              NaN
# 28    Jan 2014-current            NaN               NaN              NaN
# 29    Jan 2014-current            NaN               NaN              NaN
# 30   Jan 2014-Dec 2018            NaN               NaN              NaN
# 31                 NaN            NaN               NaN              NaN
# 32    Jan 2014-current            NaN               NaN              NaN
#
#    Period of Max
# 0     Wind Speed
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31           NaN
# 32           NaN

# %% [markdown]
# Problematic Entries:
# - Upper Peirce (index 17) --> use index 18's Coordinates instead [actual name: Upper Peirce Reservoir]
# - Choa Chu Kang (index 31) --> use index 32's Coordinates instead [actual name: Choa Chu Kang (West)]
#
# Index to delete:
# - 0, 1, 2, 18, 32

# %%
#### Fix the Station Name and Geocordinates of Problematic Entries
page_2.loc[17, "Unnamed: 0"] = "Upper Peirce Reservoir"
page_2.loc[17, "Position"] = page_2.loc[18, "Position"]

page_2.loc[31, "Unnamed: 0"] = "Choa Chu Kang (West)"
page_2.loc[31, "Position"] = page_2.loc[32, "Position"]

#### Delete extra rows
page_2.drop([0, 1, 2, 18, 32], axis=0, inplace=True)
page_2.reset_index(drop=True, inplace=True)

#### Subset Station Name and coordinates columns and Rename Columns
page_2 = page_2[["Unnamed: 0", "Position"]].copy()
page_2.rename(columns={"Unnamed: 0" : "station", "Position": "coordinates"}, inplace=True)

# %%
page_2
# Out:
#                    station      coordinates
# 0               Ulu Pandan  1.3329 103.7556
# 1                Serangoon  1.3382 103.8657
# 2            Jurong (East)  1.3262 103.7354
# 3                   Mandai  1.4036 103.7898
# 4            Upper Thomson  1.3416 103.8106
# 5                 Buangkok  1.3837 103.8860
# 6          Boon Lay (West)  1.3275 103.7042
# 7            Bukit Panjang  1.3824 103.7603
# 8         Kranji Reservoir  1.4387 103.7363
# 9            Tanjong Pagar  1.2740 103.8482
# 10        Admiralty (West)  1.4582 103.7953
# 11              Queenstown  1.2937 103.8125
# 12          Tanjong Katong  1.3070 103.8907
# 13               Chai Chee  1.3277 103.9203
# 14  Upper Peirce Reservoir  1.3700 103.8050
# 15              Kent Ridge  1.2923 103.7815
# 16                Somerset  1.3004 103.8372
# 17                 Punggol  1.4029 103.9092
# 18               Tuas West  1.3247 103.6351
# 19                   Simei  1.3437 103.9444
# 20               Toa Payoh  1.3415 103.8519
# 21                    Tuas  1.3199 103.6616
# 22             Bukit Timah  1.3191 103.8191
# 23                  Yishun  1.4301 103.8308
# 24             Buona Vista  1.2841 103.7886
# 25       Pasir Ris Central  1.3679 103.9489
# 26          Jurong (North)  1.3505 103.7134
# 27    Choa Chu Kang (West)  1.3746 103.6938

# %% [markdown]
# #### Page 3

# %%
page_3 = all_tables[2]
page_3
# Out:
#          Unnamed: 0           Position    Period of Daily           Period of  \
# 0               NaN                NaN       Rain Records  30,60,120-Min Rain
# 1               NaN                NaN                NaN             Records
# 2           Station  Lat.(N) Long. (E)                NaN                 NaN
# 3   Serangoon North    1.3606 103.8697  Jun 2009-Apr 2017   Jan 2014-Apr 2017
# 4      Lim Chu Kang    1.4385 103.7013   Jan 2010-current    Jan 2014-current
# 5     Marine Parade    1.3065 103.9107   May 2009-current    Jan 2014-current
# 6     Choa Chu Kang                NaN                NaN                 NaN
# 7         (Central)    1.3819 103.7386   Dec 2009-current    Jan 2014-current
# 8       Dhoby Ghaut    1.2994 103.8461   Sep 2010-current    Jan 2014-current
# 9    Nicoll Highway    1.3011 103.8666   Sep 2010-current    Jan 2014-current
# 10   Botanic Garden    1.3087 103.8180   Sep 2010-current    Jan 2014-current
# 11          Whampoa    1.3214 103.8577   Oct 2011-current    Jan 2014-current
#
#    Period of Mean Period of Max and Period of Mean.1 Period of Max
# 0     Temperature   Min Temperature       Wind Speed    Wind Speed
# 1             NaN               NaN              NaN           NaN
# 2             NaN               NaN              NaN           NaN
# 3             NaN               NaN              NaN           NaN
# 4             NaN               NaN              NaN           NaN
# 5             NaN               NaN              NaN           NaN
# 6             NaN               NaN              NaN           NaN
# 7             NaN               NaN              NaN           NaN
# 8             NaN               NaN              NaN           NaN
# 9             NaN               NaN              NaN           NaN
# 10            NaN               NaN              NaN           NaN
# 11            NaN               NaN              NaN           NaN

# %% [markdown]
# Problematic Entries:
# - Choa Chu Kang (index 6) --> use index 7's Coordinates instead [actual name: Choa Chu Kang (Central)]
#
# Index to delete:
# - 0, 1, 2, 7

# %%
#### Fix the Station Name and Geocordinates of Problematic Entries
page_3.loc[6, "Unnamed: 0"] = "Choa Chu Kang"
page_3.loc[6, "Position"] = page_3.loc[7, "Position"]

#### Delete extra rows
page_3.drop([0, 1, 2, 7], axis=0, inplace=True)
page_3.reset_index(drop=True, inplace=True)

#### Subset Station Name and coordinates columns and Rename Columns
page_3 = page_3[["Unnamed: 0", "Position"]].copy()
page_3.rename(columns={"Unnamed: 0" : "station", "Position": "coordinates"}, inplace=True)

# %%
page_3
# Out:
#            station      coordinates
# 0  Serangoon North  1.3606 103.8697
# 1     Lim Chu Kang  1.4385 103.7013
# 2    Marine Parade  1.3065 103.9107
# 3    Choa Chu Kang  1.3819 103.7386
# 4      Dhoby Ghaut  1.2994 103.8461
# 5   Nicoll Highway  1.3011 103.8666
# 6   Botanic Garden  1.3087 103.8180
# 7          Whampoa  1.3214 103.8577

# %% [markdown]
# ### Combine 3 Tables and Create Coordinates Columns

# %%
df = pd.concat([page_1, page_2, page_3])
df.reset_index(drop=True, inplace=True)
df
# Out:
#            station      coordinates
# 0       Paya Lebar  1.3524 103.9007
# 1           Tengah  1.3858 103.7114
# 2           Changi  1.3678 103.9826
# 3          Seletar  1.4166 103.8654
# 4         Tai Seng  1.3399 103.8878
# ..             ...              ...
# 58   Choa Chu Kang  1.3819 103.7386
# 59     Dhoby Ghaut  1.2994 103.8461
# 60  Nicoll Highway  1.3011 103.8666
# 61  Botanic Garden  1.3087 103.8180
# 62         Whampoa  1.3214 103.8577
#
# [63 rows x 2 columns]

# %%
df["latitude"] = df["coordinates"].apply(lambda x: x.split(" ")[0])
df["longitude"] = df["coordinates"].apply(lambda x: x.split(" ")[1])
df.drop(columns=["coordinates"], inplace=True)

df
# Out:
#            station latitude longitude
# 0       Paya Lebar   1.3524  103.9007
# 1           Tengah   1.3858  103.7114
# 2           Changi   1.3678  103.9826
# 3          Seletar   1.4166  103.8654
# 4         Tai Seng   1.3399  103.8878
# ..             ...      ...       ...
# 58   Choa Chu Kang   1.3819  103.7386
# 59     Dhoby Ghaut   1.2994  103.8461
# 60  Nicoll Highway   1.3011  103.8666
# 61  Botanic Garden   1.3087  103.8180
# 62         Whampoa   1.3214  103.8577
#
# [63 rows x 3 columns]

# %% [markdown]
# ### Export at Shapefile

# %%
gdf = gpd.GeoDataFrame(df, geometry= gpd.points_from_xy(df['longitude'], df['latitude']), crs='epsg:4326')
gdf.drop(columns=["latitude", "longitude"], inplace=True)
gdf
# Out:
#            station                   geometry
# 0       Paya Lebar  POINT (103.90070 1.35240)
# 1           Tengah  POINT (103.71140 1.38580)
# 2           Changi  POINT (103.98260 1.36780)
# 3          Seletar  POINT (103.86540 1.41660)
# 4         Tai Seng  POINT (103.88780 1.33990)
# ..             ...                        ...
# 58   Choa Chu Kang  POINT (103.73860 1.38190)
# 59     Dhoby Ghaut  POINT (103.84610 1.29940)
# 60  Nicoll Highway  POINT (103.86660 1.30110)
# 61  Botanic Garden  POINT (103.81800 1.30870)
# 62         Whampoa  POINT (103.85770 1.32140)
#
# [63 rows x 2 columns]

# %%
export_df_to_shapefile(gdf, "weather_stations")
# Out:
#            station                   geometry
# 0       Paya Lebar  POINT (103.90070 1.35240)
# 1           Tengah  POINT (103.71140 1.38580)
# 2           Changi  POINT (103.98260 1.36780)
# 3          Seletar  POINT (103.86540 1.41660)
# 4         Tai Seng  POINT (103.88780 1.33990)
# ..             ...                        ...
# 58   Choa Chu Kang  POINT (103.73860 1.38190)
# 59     Dhoby Ghaut  POINT (103.84610 1.29940)
# 60  Nicoll Highway  POINT (103.86660 1.30110)
# 61  Botanic Garden  POINT (103.81800 1.30870)
# 62         Whampoa  POINT (103.85770 1.32140)
#
# [63 rows x 2 columns]
